# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [16, 4]

# %%
data = pd.read_csv("../data/tabla_generacion_energia.csv", parse_dates=["fecha"], index_col="fecha")

# %%
data.head()
# Out:
#                        potencia  temp   hum  presion dir   vel  nub situacion
# fecha
# 2019-05-30 12:00:00  866.133333   5.0  90.0   1023.1   E   9.4  8.0  Cubierto
# 2019-05-30 13:00:00  732.900000   6.4  88.0   1023.5   E   3.6  8.0  Cubierto
# 2019-05-30 14:00:00  455.018868   7.6  83.0   1023.4  SE  11.2  7.0    Nuboso
# 2019-05-30 15:00:00  191.666667   8.4  75.0   1022.9   E  14.8  7.0    Nuboso
# 2019-05-30 16:00:00   60.366667   9.6  66.0   1022.3   E  16.6  6.0    Nuboso

# %%
data = data.asfreq("H")

# %%
numerical = ["potencia", "temp", "hum", "presion", "vel"]
categorical = ["nub", "dir"]

# %%
data.plot(y=numerical, subplots=True, layout=(len(numerical), 1), figsize=(16, 12));
