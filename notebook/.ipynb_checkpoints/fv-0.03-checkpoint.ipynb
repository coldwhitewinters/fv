# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.tsa.api as tsa
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pmd
from tbats import BATS, TBATS

# %matplotlib inline

# Cuidado al usar Prophet. De-registra los convertores de pandas para matplotlib, ocasionando bugs.
from fbprophet import Prophet

# %%
pd.plotting.register_matplotlib_converters() # Volvemos a registrar los convertores.
plt.rcParams['figure.figsize'] = [16, 4]

# %% [markdown]
# ### Carga y limpieza de datos

# %%
# Cargamos los datos
data_hourly = pd.read_excel("../data/datos.xlsx", sheet_name="Hoja2")
data_hourly.head(10)
# Out:
#         Fecha Hora UTC  Temp. (ºC) H.Rel (%) Presion/ Geopot.  Dir. vi.  \
# 0  01/04/2019      23Z        19.3       86%       1013.2 Hpa   20º (N)
# 1  01/04/2019      22Z        21.0       77%       1013.0 Hpa   20º (N)
# 2  01/04/2019      21Z        25.2       58%       1013.5 Hpa  360º (N)
# 3  01/04/2019      20Z        27.0       48%       1013.4 Hpa  360º (N)
# 4  01/04/2019      19Z        26.6       47%       1013.5 Hpa   20º (N)
# 5  01/04/2019      18Z        27.2       40%       1013.8 Hpa  360º (N)
# 6  01/04/2019      17Z        27.0       45%       1014.6 Hpa  360º (N)
# 7  01/04/2019      16Z        26.2       47%       1015.6 Hpa  360º (N)
# 8  01/04/2019      15Z        24.7       50%       1016.0 Hpa  360º (N)
# 9  01/04/2019      14Z        22.8       56%       1016.5 Hpa  360º (N)
#
#    Vel. vi. (Km/h) Nub. Nubes bajas Nubes medias Nubes altas Prec. (mm)  \
# 0             11.2  2/8           -       1/8 AC          CI          -
# 1             13.0  3/8           -       2/8 AC          CI          -
# 2             14.8  5/8           -       4/8 AC          CI          -
# 3             18.4  5/8           -       4/8 AC          CI          -
# 4             18.4  4/8           -       4/8 AC           -          -
# 5             20.5  1/8           -       1/8 AC           -          -
# 6             22.3  1/8           -       1/8 AC           -          -
# 7             18.4  1/8           -       1/8 AC           -          -
# 8             14.8  1/8           -       1/8 AC           -          -
# 9             16.6  1/8           -       1/8 AC           -          -
#
#   T. max (ºC) T. min (ºC)        Situacion
# 0           -           -    Algunas nubes
# 1           -           -  Nubes dispersas
# 2           -           -           Nuboso
# 3           -           -           Nuboso
# 4           -           -  Nubes dispersas
# 5           -           -    Algunas nubes
# 6           -           -    Algunas nubes
# 7           -           -    Algunas nubes
# 8           -           -    Algunas nubes
# 9           -           -    Algunas nubes

# %% [markdown]
# Comenzamos por combinar las columnas de fecha y hora para crear un indice en formato datetime y acomodamos los nombres de las columnas para acceso más conveniente.

# %%
data_hourly["Hora UTC"] = data_hourly["Hora UTC"].map(lambda x: x[:-1])
data_hourly["fecha"] = pd.to_datetime(data_hourly["Fecha"] + " " + data_hourly["Hora UTC"], format="%d/%m/%Y %H")
data_hourly = data_hourly.set_index("fecha").sort_index()
data_hourly = data_hourly.drop(labels=["Hora UTC", "Fecha"], axis=1)
data_hourly.columns = ["temp", "hum", "presion", "dir", "vel", "nub", "n_bajas", "n_medias", "n_altas", "prec", "t_max", "t_min", "situacion"]
data_hourly.head()
# Out:
#                      temp  hum     presion        dir   vel   nub n_bajas  \
# fecha
# 2019-04-01 00:00:00  20.1  85%  1016.3 Hpa  070º (E )  14.8  6/8        -
# 2019-04-01 01:00:00  19.2  93%  1016.7 Hpa    70º (E)   9.4   4/8       -
# 2019-04-01 02:00:00  18.5  95%  1016.7 Hpa    70º (E)   3.6   0/8       -
# 2019-04-01 03:00:00  15.2  96%  1016.7 Hpa   180º (S)   5.4   0/8       -
# 2019-04-01 04:00:00  16.2  95%  1016.3 Hpa   110º (E)   7.6   4/8       -
#
#                     n_medias n_altas prec t_max t_min  \
# fecha
# 2019-04-01 00:00:00  2/8  AC      CI    -  28.9  18.7
# 2019-04-01 01:00:00        -   CI/CS    -     -     -
# 2019-04-01 02:00:00        -       -    -     -     -
# 2019-04-01 03:00:00        -       -    -     -     -
# 2019-04-01 04:00:00        -   CI/CS    -     -     -
#
#                                     situacion
# fecha
# 2019-04-01 00:00:00                    Nuboso
# 2019-04-01 01:00:00           Nubes dispersas
# 2019-04-01 02:00:00                 Despejado
# 2019-04-01 03:00:00        Despejado, neblina
# 2019-04-01 04:00:00  Nubes dispersas, neblina

# %% [markdown]
# Revisamos los valores faltantes.

# %%
data_hourly.isna().sum()
# Out:
# temp          4
# hum           6
# presion       0
# dir           0
# vel          10
# nub           0
# n_bajas       0
# n_medias      0
# n_altas       0
# prec          0
# t_max         0
# t_min         0
# situacion     0
# dtype: int64

# %% [markdown]
# Ahora vamos a transformar algunas columnas. Para procesarlas vamos a tener que asegurarnos de que sigan un formato coherente. Nos fijamos qué observaciones siguen un patrón diferente y vemos si las descartamos o podemos arreglarlas. Luego aplicamos la transformación.

# %% [markdown]
# #### Humedad

# %%
# Observaciones donde la columna humedad no sigue el formato esperado.
mask = ~data_hourly.hum.str.match("^\d{,3}\%$", na=False)
data_hourly[mask]
# Out:
#                      temp  hum     presion        dir   vel   nub    n_bajas  \
# fecha
# 2019-05-26 15:00:00  10.2  NaN  1011.2 Hpa  320º (NW)   9.3  8/8   6/8   SC
# 2019-06-21 11:00:00   3.4  NaN  1019.5 Hpa      calma   NaN  5/8           -
# 2019-06-22 12:00:00   7.8  NaN  1019.3 Hpa  230º (SW)   7.4  6/8           -
# 2019-06-27 23:00:00   4.1  NaN  1010.5 Hpa  360º (N )   9.3  8/8           -
# 2019-07-09 17:00:00   4.6  NaN  1020.9 Hpa  320º (NW)   5.6  4/8           -
# 2019-08-06 07:00:00   3.4  NaN  1013.8 Hpa  340º (N )  11.1  0/8           -
#
#                     n_medias n_altas prec t_max t_min        situacion
# fecha
# 2019-05-26 15:00:00       AC     N/D    -     -     -         Cubierto
# 2019-06-21 11:00:00        -      CI    -     -     -   Nuboso, niebla
# 2019-06-22 12:00:00        -      CI    -  10.5  24.0  Nuboso, neblina
# 2019-06-27 23:00:00  5/8  AC      CI    -     -     -         Cubierto
# 2019-07-09 17:00:00        -      CI    -     -     -  Nubes dispersas
# 2019-08-06 07:00:00        -       -    -     -     -        Despejado

# %% [markdown]
# La columna de humedad no tiene problemas, solo datos faltantes, así que la transformamos a numérico.

# %%
data_hourly.hum = pd.to_numeric(data_hourly.hum.str.strip("%"))
data_hourly.head()
# Out:
#                      temp   hum     presion        dir   vel   nub n_bajas  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0  1016.3 Hpa  070º (E )  14.8  6/8        -
# 2019-04-01 01:00:00  19.2  93.0  1016.7 Hpa    70º (E)   9.4   4/8       -
# 2019-04-01 02:00:00  18.5  95.0  1016.7 Hpa    70º (E)   3.6   0/8       -
# 2019-04-01 03:00:00  15.2  96.0  1016.7 Hpa   180º (S)   5.4   0/8       -
# 2019-04-01 04:00:00  16.2  95.0  1016.3 Hpa   110º (E)   7.6   4/8       -
#
#                     n_medias n_altas prec t_max t_min  \
# fecha
# 2019-04-01 00:00:00  2/8  AC      CI    -  28.9  18.7
# 2019-04-01 01:00:00        -   CI/CS    -     -     -
# 2019-04-01 02:00:00        -       -    -     -     -
# 2019-04-01 03:00:00        -       -    -     -     -
# 2019-04-01 04:00:00        -   CI/CS    -     -     -
#
#                                     situacion
# fecha
# 2019-04-01 00:00:00                    Nuboso
# 2019-04-01 01:00:00           Nubes dispersas
# 2019-04-01 02:00:00                 Despejado
# 2019-04-01 03:00:00        Despejado, neblina
# 2019-04-01 04:00:00  Nubes dispersas, neblina

# %% [markdown]
# #### Presion

# %%
# Observaciones donde la presión no sigue el patrón que debería
mask = ~data_hourly.presion.str.match("^\s*\d{3,4}[.]\d\s*Hpa\s*$", na=False)
data_hourly[mask]
# Out:
#                      temp   hum           presion        dir   vel   nub  \
# fecha
# 2019-06-23 00:00:00  17.6  62.0                 -  320º (NW)   3.7  7/8
# 2019-06-28 10:00:00   4.4  89.0                 -   180º (S)   9.4   6/8
# 2019-07-16 01:00:00   2.8  86.0  234 m (1000 Hpa)   200º (S)   5.4   0/8
# 2019-07-25 13:00:00   3.0  62.0                 -  110º (E )   7.4  7/8
# 2019-09-03 05:00:00  23.7  17.0                 -  230º (SW)  18.5  0/8
#
#                     n_bajas n_medias n_altas prec t_max t_min        situacion
# fecha
# 2019-06-23 00:00:00       -        -      CI    -  19.1   8.2  Nuboso, neblina
# 2019-06-28 10:00:00       -   1/8 AC   CI/CS    -     -     -           Nuboso
# 2019-07-16 01:00:00       -        -       -    -     -     -        Despejado
# 2019-07-25 13:00:00       -  2/8  AC      CI    -     -     -           Nuboso
# 2019-09-03 05:00:00       -        -       -    -     -     -        Despejado

# %% [markdown]
# Tenemos un valor con un formato diferente al resto y datos faltantes. Solo nos interesa el valor numérico, así que lo extraemos y asignamos NA a las observaciones problemáticas.

# %%
ext = data_hourly.presion.str.extract("^\s*(\d{3,4}[.]\d)\s*Hpa\s*$") # Extrae y asigna NA a las que no coinciden con el patrón.
data_hourly.presion = pd.to_numeric(ext[0])
data_hourly.head()
# Out:
#                      temp   hum  presion        dir   vel   nub n_bajas  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0   1016.3  070º (E )  14.8  6/8        -
# 2019-04-01 01:00:00  19.2  93.0   1016.7    70º (E)   9.4   4/8       -
# 2019-04-01 02:00:00  18.5  95.0   1016.7    70º (E)   3.6   0/8       -
# 2019-04-01 03:00:00  15.2  96.0   1016.7   180º (S)   5.4   0/8       -
# 2019-04-01 04:00:00  16.2  95.0   1016.3   110º (E)   7.6   4/8       -
#
#                     n_medias n_altas prec t_max t_min  \
# fecha
# 2019-04-01 00:00:00  2/8  AC      CI    -  28.9  18.7
# 2019-04-01 01:00:00        -   CI/CS    -     -     -
# 2019-04-01 02:00:00        -       -    -     -     -
# 2019-04-01 03:00:00        -       -    -     -     -
# 2019-04-01 04:00:00        -   CI/CS    -     -     -
#
#                                     situacion
# fecha
# 2019-04-01 00:00:00                    Nuboso
# 2019-04-01 01:00:00           Nubes dispersas
# 2019-04-01 02:00:00                 Despejado
# 2019-04-01 03:00:00        Despejado, neblina
# 2019-04-01 04:00:00  Nubes dispersas, neblina

# %% [markdown]
# #### Dirección del viento

# %%
# Observaciones de dirección con formato diferente al esperado.
mask = ~data_hourly.dir.str.match("^\s*\d{1,3}.\s*[(]\s*[NESW]{,2}\s*[)]\s*$", na=False)
data_hourly[mask]
# Out:
#                      temp    hum  presion    dir  vel   nub n_bajas n_medias  \
# fecha
# 2019-04-01 06:00:00  15.6   96.0   1015.8  calma  NaN  5/8        -  2/8  AC
# 2019-06-01 06:00:00   7.1   93.0   1016.8  calma  NaN  8/8        -  8/8  AC
# 2019-06-21 11:00:00   3.4    NaN   1019.5  calma  NaN  5/8        -        -
# 2019-06-22 00:00:00   9.9   93.0   1019.5  calma  NaN  7/8        -  4/8  AC
# 2019-07-07 12:00:00  -0.4   95.0   1026.9  calma  NaN  5/8        -        -
# 2019-07-31 09:00:00   3.9  100.0   1010.3  calma  NaN  2/8        -        -
# 2019-08-10 12:00:00  -0.4   95.0   1017.1  calma  NaN  0/8        -        -
# 2019-08-22 12:00:00   4.8   93.0   1030.6  calma  NaN  8/8        -  8/8  AC
# 2019-08-26 12:00:00   9.4   93.0   1018.7  calma  NaN  0/8        -        -
# 2019-08-27 12:00:00  10.6   82.0   1024.7  calma  NaN  7/8        -  4/8  AC
#
#                     n_altas       prec t_max t_min              situacion
# fecha
# 2019-04-01 06:00:00      CI          -     -     -        Nuboso, neblina
# 2019-06-01 06:00:00     N/D          -     -     -               Cubierto
# 2019-06-21 11:00:00      CI          -     -     -         Nuboso, niebla
# 2019-06-22 00:00:00      CI          -  14.2   3.2                 Nuboso
# 2019-07-07 12:00:00      CI          -   2.0  -4.8                 Nuboso
# 2019-07-31 09:00:00      CI          -     -     -  Algunas nubes, niebla
# 2019-08-10 12:00:00       -          -   1.4  -4.6              Despejado
# 2019-08-22 12:00:00     N/D   0.2(24h)   5.0   2.5               Cubierto
# 2019-08-26 12:00:00       -          -   9.6   3.6      Despejado, niebla
# 2019-08-27 12:00:00      CI          -  11.6   7.2                 Nuboso

# %% [markdown]
# Nos quedamos solo con el punto cardinal y le asignamos "-" a la dirección en aquellas observaciones que corresponden a días sin viento, como también cero a la velocidad.

# %%
ext = data_hourly.dir.str.extract("^\s*\d{1,3}.\s*[(]\s*([NESW]{,2})\s*[)]\s*$")
data_hourly.loc[data_hourly.dir != "calma", "dir"] = ext[0]
data_hourly.loc[data_hourly.dir == "calma", ["dir", "vel"]] = ["-", 0]

# %% [markdown]
# Comprobamos si los días con velocidad cero coinciden con aquellos días con dirección nula.

# %%
(data_hourly.vel == 0).equals(data_hourly.dir == "-")
# Out:
# False

# %% [markdown]
# No coinciden, así que lo revisamos mejor.

# %%
data_hourly[(data_hourly.vel == 0) != (data_hourly.dir == "-")].head(10)
# Out:
#                      temp   hum  presion dir  vel  nub n_bajas n_medias  \
# fecha
# 2019-04-01 05:00:00  16.0  96.0   1016.6   N  0.0  4/8       -        -
# 2019-04-02 02:00:00  17.2  93.0   1012.8   N  0.0  0/8       -        -
# 2019-04-03 05:00:00   9.0  96.0   1014.8   N  0.0  0/8       -        -
# 2019-04-04 00:00:00  12.9  73.0   1007.1   N  0.0  0/8       -        -
# 2019-04-05 21:00:00  18.2  47.0   1020.2   N  0.0  0/8       -        -
# 2019-04-05 22:00:00  14.1  67.0   1020.7   N  0.0  0/8       -        -
# 2019-04-06 00:00:00   8.6  87.0   1021.6   N  0.0  0/8       -        -
# 2019-04-06 01:00:00   7.7  87.0   1022.1   N  0.0  0/8       -        -
# 2019-04-06 02:00:00   6.6  88.0   1022.2   N  0.0  0/8       -        -
# 2019-04-06 04:00:00   7.1  89.0   1021.7   N  0.0  0/8       -        -
#
#                     n_altas prec t_max t_min                 situacion
# fecha
# 2019-04-01 05:00:00   CI/CS    -     -     -  Nubes dispersas, neblina
# 2019-04-02 02:00:00       -    -     -     -                 Despejado
# 2019-04-03 05:00:00       -    -     -     -                 Despejado
# 2019-04-04 00:00:00       -    -  23.4  11.9                 Despejado
# 2019-04-05 21:00:00       -    -     -     -                 Despejado
# 2019-04-05 22:00:00       -    -     -     -                 Despejado
# 2019-04-06 00:00:00       -    -  20.0   8.6                 Despejado
# 2019-04-06 01:00:00       -    -     -     -                 Despejado
# 2019-04-06 02:00:00       -    -     -     -                 Despejado
# 2019-04-06 04:00:00       -    -     -     -                 Despejado

# %% [markdown]
# Parece que en casi todos los días con velocidad cero la dirección asignada fue N(0°).

# %%
data_hourly[data_hourly.vel == 0].dir.unique()
# Out:
# array(['N', '-'], dtype=object)

# %% [markdown]
# En efecto, ese es el caso, por lo que procedemos a reemplazar todos esos N con "-".

# %%
data_hourly.loc[data_hourly.vel == 0, "dir"] = "-"

# %% [markdown]
# #### Nubosidad

# %%
data_hourly.nub.unique()
# Out:
# array(['6/8 ', '4/8', '0/8', '5/8 ', '7/8', '6/8', '3/8', '5/8', '1/8',
#        '2/8', '2/8 ', 'N/D', '8/8', '8/8 ', '0/8 ', '7/8 ', '3/8 ',
#        '1/8 ', '4/8 ', 'N/D '], dtype=object)

# %% [markdown]
# Hay algunos espacios al final y valores no disponibles. Ya sabemos que la humedad está medida en octas, por lo que no quedamos con el numerador solamente y asignamos -1 a los valores "N/D" y pasamos a numérico.

# %%
#data_hourly.nub = data_hourly.nub.str.strip()
data_hourly.nub = data_hourly.nub.apply(lambda x: x[0])
data_hourly.loc[data_hourly.nub == "N", "nub"] = 9

# %%
data_hourly.nub = pd.to_numeric(data_hourly.nub)

# %%
data_hourly.head()
# Out:
#                      temp   hum  presion dir   vel  nub n_bajas n_medias  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0   1016.3   E  14.8    6       -  2/8  AC
# 2019-04-01 01:00:00  19.2  93.0   1016.7   E   9.4    4       -        -
# 2019-04-01 02:00:00  18.5  95.0   1016.7   E   3.6    0       -        -
# 2019-04-01 03:00:00  15.2  96.0   1016.7   S   5.4    0       -        -
# 2019-04-01 04:00:00  16.2  95.0   1016.3   E   7.6    4       -        -
#
#                     n_altas prec t_max t_min                 situacion
# fecha
# 2019-04-01 00:00:00      CI    -  28.9  18.7                    Nuboso
# 2019-04-01 01:00:00   CI/CS    -     -     -           Nubes dispersas
# 2019-04-01 02:00:00       -    -     -     -                 Despejado
# 2019-04-01 03:00:00       -    -     -     -        Despejado, neblina
# 2019-04-01 04:00:00   CI/CS    -     -     -  Nubes dispersas, neblina

# %%
data_hourly.nub.unique()
# Out:
# array([6, 4, 0, 5, 7, 3, 1, 2, 9, 8], dtype=int64)

# %% [markdown]
# Una inspección a las observaciones con valores -1 de nubosidad resulta ser reveladora. Ese valor corresponde a días de niebla.

# %%
data_hourly[data_hourly.nub == 9].head(10)
# Out:
#                      temp    hum  presion dir   vel  nub n_bajas n_medias  \
# fecha
# 2019-04-02 10:00:00  17.9   98.0   1010.7  NW  11.2    9       -        -
# 2019-04-02 11:00:00  17.6  100.0   1010.9  NW  11.2    9       -        -
# 2019-04-02 12:00:00  18.0  100.0   1010.6   N  11.2    9       -        -
# 2019-04-02 13:00:00  19.6  100.0   1010.6  NW  13.0    9       -        -
# 2019-04-04 08:00:00  11.9  100.0   1001.0   N   3.6    9       -        -
# 2019-04-04 09:00:00  12.6  100.0   1000.9   N   7.6    9       -        -
# 2019-04-04 10:00:00  13.2   98.0   1000.6   E   7.6    9       -        -
# 2019-05-04 05:00:00  10.7   96.0   1015.4   E  16.6    9       -        -
# 2019-05-04 06:00:00  11.9   98.0   1016.3   E  14.8    9       -        -
# 2019-05-04 07:00:00  11.8   98.0   1016.9   E  14.8    9       -        -
#
#                     n_altas prec t_max t_min situacion
# fecha
# 2019-04-02 10:00:00       -    -     -     -    Niebla
# 2019-04-02 11:00:00       -    -     -     -    Niebla
# 2019-04-02 12:00:00       -    -  19.2  15.0    Niebla
# 2019-04-02 13:00:00       -    -     -     -    Niebla
# 2019-04-04 08:00:00       -    -     -     -    Niebla
# 2019-04-04 09:00:00       -    -     -     -    Niebla
# 2019-04-04 10:00:00       -    -     -     -    Niebla
# 2019-05-04 05:00:00       -    -     -     -    Niebla
# 2019-05-04 06:00:00       -    -     -     -    Niebla
# 2019-05-04 07:00:00       -    -     -     -    Niebla

# %%
data_hourly[data_hourly.nub == -1].situacion.unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# #### Precipitaciones

# %%
data_hourly.prec.unique()
# Out:
# array(['-', '17.0(24h)', '11.0(6h)', '2.0(6h)', '12.0(24h)', '20.0(6h)',
#        '0.6(6h)', '21.0(24h)', '4.0(24h)', '6.0(6h)', '3.0(6h)',
#        '8.0(24h)', 'Ip(24h)', 'Ip(6h)', '1.0(6h)', '18.0(6h)',
#        '22.0(24h)', '0.2(6h)', '0.7(6h)', '0.9(24h)', '3.0(24h)',
#        '23.0(6h)', '5.0(6h)', '28.0(24h)', '45.0(24h)', '0.5(6h)',
#        '0.6(24h)', '35.0(6h)', '39.0(24h)', '13.0(24h)', '27.0(6h)',
#        '13.0(6h)', '56.0(24h)', '0.4(6h)', ' 0.8(6h) ', '2.0(24h)',
#        '0.3(6h)', '62.0(12h)', ' 0.2(24h)', '5.0(24h)'], dtype=object)

# %%
data_hourly.loc[~data_hourly.prec.str.match("\s*(\d{,2}.\d).*", na=False), "prec"].unique()
# Out:
# array(['-', 'Ip(24h)', 'Ip(6h)'], dtype=object)

# %% [markdown]
# La columna de precipitacion contiene la combinación de dos valores: la cantidad en mm y lo que parece ser una aproximación al número de horas que ha estado precipitando. También hay un valor denominado "Ip" que corresponde a precipitaciones inapreciables. Lo que vamos a hacer es quedarnos solo con la información numérica de la precipitacion en mm y descartar todo lo demás. A las celdas con "-" y "Ip" le vamos a asignar 0.

# %%
mask = (data_hourly.prec == "Ip(24h)") | (data_hourly.prec == "Ip(6h)") | (data_hourly.prec == "-")
data_hourly.loc[mask, "prec"] = 0.0

# %%
extr = data_hourly.prec.str.extract("\s*(\d{,2}.\d).*")[0]

# %%
data_hourly.loc[~extr.isna(), "prec"] = extr.dropna()

# %%
data_hourly.prec = pd.to_numeric(data_hourly.prec)

# %%
data_hourly.prec.unique()
# Out:
# array([ 0. , 17. , 11. ,  2. , 12. , 20. ,  0.6, 21. ,  4. ,  6. ,  3. ,
#         8. ,  1. , 18. , 22. ,  0.2,  0.7,  0.9, 23. ,  5. , 28. , 45. ,
#         0.5, 35. , 39. , 13. , 27. , 56. ,  0.4,  0.8,  0.3, 62. ])

# %% [markdown]
# #### Temperaturas máximas y mínimas

# %%
data_hourly.loc[:, ["temp", "t_max", "t_min"]].head(25)
# Out:
#                      temp t_max t_min
# fecha
# 2019-04-01 00:00:00  20.1  28.9  18.7
# 2019-04-01 01:00:00  19.2     -     -
# 2019-04-01 02:00:00  18.5     -     -
# 2019-04-01 03:00:00  15.2     -     -
# 2019-04-01 04:00:00  16.2     -     -
# 2019-04-01 05:00:00  16.0     -     -
# 2019-04-01 06:00:00  15.6     -     -
# 2019-04-01 07:00:00  15.2     -     -
# 2019-04-01 08:00:00  15.0     -     -
# 2019-04-01 09:00:00  13.6     -     -
# 2019-04-01 10:00:00  13.5     -     -
# 2019-04-01 11:00:00  13.4     -     -
# 2019-04-01 12:00:00  17.2  20.1  12.5
# 2019-04-01 13:00:00  20.4     -     -
# 2019-04-01 14:00:00  22.8     -     -
# 2019-04-01 15:00:00  24.7     -     -
# 2019-04-01 16:00:00  26.2     -     -
# 2019-04-01 17:00:00  27.0     -     -
# 2019-04-01 18:00:00  27.2     -     -
# 2019-04-01 19:00:00  26.6     -     -
# 2019-04-01 20:00:00  27.0     -     -
# 2019-04-01 21:00:00  25.2     -     -
# 2019-04-01 22:00:00  21.0     -     -
# 2019-04-01 23:00:00  19.3     -     -
# 2019-04-02 00:00:00  19.2  28.2  17.2

# %% [markdown]
# Las temperaturas máximas y mínimas se anotan al final del período correspondiente. Por lo tanto podemos reemplazar todos los "-" con NA y después realizar un backfill.

# %%
data_hourly.loc[data_hourly.t_max == "-", "t_max"] = np.nan
data_hourly.loc[data_hourly.t_min == "-", "t_min"] = np.nan

# %%
data_hourly.t_max = pd.to_numeric(data_hourly.t_max)
data_hourly.t_min = pd.to_numeric(data_hourly.t_min)

# %%
data_hourly.t_max = data_hourly.t_max.fillna(method="bfill")
data_hourly.t_min = data_hourly.t_min.fillna(method="bfill")

# %%
data_hourly.head()
# Out:
#                      temp   hum  presion dir   vel  nub n_bajas n_medias  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0   1016.3   E  14.8    6       -  2/8  AC
# 2019-04-01 01:00:00  19.2  93.0   1016.7   E   9.4    4       -        -
# 2019-04-01 02:00:00  18.5  95.0   1016.7   E   3.6    0       -        -
# 2019-04-01 03:00:00  15.2  96.0   1016.7   S   5.4    0       -        -
# 2019-04-01 04:00:00  16.2  95.0   1016.3   E   7.6    4       -        -
#
#                     n_altas  prec  t_max  t_min                 situacion
# fecha
# 2019-04-01 00:00:00      CI   0.0   28.9   18.7                    Nuboso
# 2019-04-01 01:00:00   CI/CS   0.0   20.1   12.5           Nubes dispersas
# 2019-04-01 02:00:00       -   0.0   20.1   12.5                 Despejado
# 2019-04-01 03:00:00       -   0.0   20.1   12.5        Despejado, neblina
# 2019-04-01 04:00:00   CI/CS   0.0   20.1   12.5  Nubes dispersas, neblina

# %% [markdown]
# #### Nubes bajas, medias y altas

# %% [markdown]
# Por último, las columnas con los datos de nubosidad baja, media y alta no nos interesan, así que las tiramos.

# %%
data_hourly = data_hourly.drop(columns=["n_bajas", "n_medias", "n_altas"])

# %%
data_hourly.head()
# Out:
#                      temp   hum  presion dir   vel  nub  prec  t_max  t_min  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0   1016.3   E  14.8    6   0.0   28.9   18.7
# 2019-04-01 01:00:00  19.2  93.0   1016.7   E   9.4    4   0.0   20.1   12.5
# 2019-04-01 02:00:00  18.5  95.0   1016.7   E   3.6    0   0.0   20.1   12.5
# 2019-04-01 03:00:00  15.2  96.0   1016.7   S   5.4    0   0.0   20.1   12.5
# 2019-04-01 04:00:00  16.2  95.0   1016.3   E   7.6    4   0.0   20.1   12.5
#
#                                     situacion
# fecha
# 2019-04-01 00:00:00                    Nuboso
# 2019-04-01 01:00:00           Nubes dispersas
# 2019-04-01 02:00:00                 Despejado
# 2019-04-01 03:00:00        Despejado, neblina
# 2019-04-01 04:00:00  Nubes dispersas, neblina

# %% [markdown]
# ### Datos faltantes

# %% [markdown]
# Verificamos qué columnas tienen datos faltantes.

# %%
data_hourly.isna().sum()
# Out:
# temp         4
# hum          6
# presion      5
# dir          0
# vel          0
# nub          0
# prec         0
# t_max        7
# t_min        7
# situacion    0
# dtype: int64

# %% [markdown]
# Revisamos los valores faltantes de temperatura.

# %%
data_hourly[data_hourly.temp.isna()]
# Out:
#                      temp  hum  presion dir    vel  nub  prec  t_max  t_min  \
# fecha
# 2019-06-22 21:00:00   NaN  0.0   1017.4   N   57.4    1   0.0   19.1    8.2
# 2019-06-23 10:00:00   NaN  0.0   1012.4   N  122.3    1   0.0   10.4    4.0
# 2019-07-26 21:00:00   NaN  0.0   1020.8   S   11.1    5   0.0   14.0    5.2
# 2019-08-30 00:00:00   NaN  0.0   1015.9   N  113.0    1   0.0   16.0    6.0
#
#                          situacion
# fecha
# 2019-06-22 21:00:00  Algunas nubes
# 2019-06-23 10:00:00  Algunas nubes
# 2019-07-26 21:00:00         Nuboso
# 2019-08-30 00:00:00  Algunas nubes

# %% [markdown]
# Esas observaciones tienen valores nulos en la columna de humedad. Nos fijamos si las observaciones con humedad 0 son las mismas.

# %%
data_hourly[data_hourly.temp.isna()].equals(data_hourly[data_hourly.hum == 0])
# Out:
# True

# %% [markdown]
# Claramente los valores de humedad cero en realidad corresponden a mediciones faltantes, así que los representamos como tal.

# %%
data_hourly.loc[data_hourly.hum == 0, "hum"] = np.nan

# %% [markdown]
# Ahora revisamos los datos faltantes en la columna de humedad.

# %%
data_hourly[data_hourly.hum.isna()]
# Out:
#                      temp  hum  presion dir    vel  nub  prec  t_max  t_min  \
# fecha
# 2019-05-26 15:00:00  10.2  NaN   1011.2  NW    9.3    8   0.0   10.2    8.2
# 2019-06-21 11:00:00   3.4  NaN   1019.5   -    0.0    5   0.0    7.3    2.2
# 2019-06-22 12:00:00   7.8  NaN   1019.3  SW    7.4    6   0.0   10.5   24.0
# 2019-06-22 21:00:00   NaN  NaN   1017.4   N   57.4    1   0.0   19.1    8.2
# 2019-06-23 10:00:00   NaN  NaN   1012.4   N  122.3    1   0.0   10.4    4.0
# 2019-06-27 23:00:00   4.1  NaN   1010.5   N    9.3    8   0.0   11.6    3.9
# 2019-07-09 17:00:00   4.6  NaN   1020.9  NW    5.6    4   0.0   16.2    5.3
# 2019-07-26 21:00:00   NaN  NaN   1020.8   S   11.1    5   0.0   14.0    5.2
# 2019-08-06 07:00:00   3.4  NaN   1013.8   N   11.1    0   0.0   10.0    3.0
# 2019-08-30 00:00:00   NaN  NaN   1015.9   N  113.0    1   0.0   16.0    6.0
#
#                            situacion
# fecha
# 2019-05-26 15:00:00         Cubierto
# 2019-06-21 11:00:00   Nuboso, niebla
# 2019-06-22 12:00:00  Nuboso, neblina
# 2019-06-22 21:00:00    Algunas nubes
# 2019-06-23 10:00:00    Algunas nubes
# 2019-06-27 23:00:00         Cubierto
# 2019-07-09 17:00:00  Nubes dispersas
# 2019-07-26 21:00:00           Nuboso
# 2019-08-06 07:00:00        Despejado
# 2019-08-30 00:00:00    Algunas nubes

# %% [markdown]
# Revisamos los datos faltantes de presión.

# %%
data_hourly[data_hourly.presion.isna()]
# Out:
#                      temp   hum  presion dir   vel  nub  prec  t_max  t_min  \
# fecha
# 2019-06-23 00:00:00  17.6  62.0      NaN  NW   3.7    7   0.0   19.1    8.2
# 2019-06-28 10:00:00   4.4  89.0      NaN   S   9.4    6   0.0    8.5    2.0
# 2019-07-16 01:00:00   2.8  86.0      NaN   S   5.4    0   0.0    3.3   -3.8
# 2019-07-25 13:00:00   3.0  62.0      NaN   E   7.4    7   0.0    9.5    0.6
# 2019-09-03 05:00:00  23.7  17.0      NaN  SW  18.5    0   0.0    2.5   -2.8
#
#                            situacion
# fecha
# 2019-06-23 00:00:00  Nuboso, neblina
# 2019-06-28 10:00:00           Nuboso
# 2019-07-16 01:00:00        Despejado
# 2019-07-25 13:00:00           Nuboso
# 2019-09-03 05:00:00        Despejado

# %% [markdown]
# Revisamos si hay fechas faltantes.

# %%
start = data_hourly.index[0]
end = data_hourly.index[-1]
missing_dates = pd.date_range(start=start, end=end, freq="H").difference(data_hourly.index)
print("Hay {} valores faltantes en las observaciones.".format(len(missing_dates)))
print("Los días y horas que faltan son:")
missing_dates
# Out:
# Hay 73 valores faltantes en las observaciones.
# Los días y horas que faltan son:
# DatetimeIndex(['2019-04-02 04:00:00', '2019-04-25 07:00:00',
#                '2019-05-22 07:00:00', '2019-05-23 02:00:00',
#                '2019-05-23 04:00:00', '2019-05-23 08:00:00',
#                '2019-05-27 17:00:00', '2019-06-13 13:00:00',
#                '2019-06-16 07:00:00', '2019-06-16 10:00:00',
#                '2019-06-16 11:00:00', '2019-06-16 12:00:00',
#                '2019-06-16 13:00:00', '2019-06-16 14:00:00',
#                '2019-06-16 15:00:00', '2019-06-16 16:00:00',
#                '2019-06-16 17:00:00', '2019-06-16 18:00:00',
#                '2019-06-16 19:00:00', '2019-06-16 20:00:00',
#                '2019-06-16 21:00:00', '2019-06-16 22:00:00',
#                '2019-06-16 23:00:00', '2019-06-17 00:00:00',
#                '2019-06-17 01:00:00', '2019-06-17 02:00:00',
#                '2019-06-17 03:00:00', '2019-06-17 04:00:00',
#                '2019-06-17 05:00:00', '2019-06-17 06:00:00',
#                '2019-06-17 07:00:00', '2019-06-17 08:00:00',
#                '2019-06-17 10:00:00', '2019-06-17 11:00:00',
#                '2019-06-17 13:00:00', '2019-06-17 16:00:00',
#                '2019-06-17 17:00:00', '2019-06-18 05:00:00',
#                '2019-06-18 08:00:00', '2019-06-18 10:00:00',
#                '2019-06-20 05:00:00', '2019-06-25 07:00:00',
#                '2019-06-28 04:00:00', '2019-07-05 07:00:00',
#                '2019-07-08 10:00:00', '2019-07-12 20:00:00',
#                '2019-07-15 05:00:00', '2019-07-15 21:00:00',
#                '2019-07-17 07:00:00', '2019-07-19 06:00:00',
#                '2019-07-19 08:00:00', '2019-07-23 04:00:00',
#                '2019-07-23 05:00:00', '2019-07-23 06:00:00',
#                '2019-07-23 07:00:00', '2019-07-23 08:00:00',
#                '2019-07-24 11:00:00', '2019-07-26 05:00:00',
#                '2019-07-26 16:00:00', '2019-08-05 08:00:00',
#                '2019-08-08 05:00:00', '2019-08-10 06:00:00',
#                '2019-08-10 08:00:00', '2019-08-13 01:00:00',
#                '2019-08-15 06:00:00', '2019-08-18 09:00:00',
#                '2019-08-18 22:00:00', '2019-08-24 21:00:00',
#                '2019-08-25 08:00:00', '2019-08-25 11:00:00',
#                '2019-08-28 00:00:00', '2019-08-31 03:00:00',
#                '2019-08-31 11:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# Le decimos a pandas que ponga los datos en frecuencia horaria, creando NA para los valores que faltan.

# %%
data_hourly = data_hourly.asfreq("H")
data_hourly.isna().sum()
# Out:
# temp         77
# hum          83
# presion      78
# dir          73
# vel          73
# nub          73
# prec         73
# t_max        80
# t_min        80
# situacion    73
# dtype: int64

# %% [markdown]
# Agregamos una columna que nos dice si la fila corresponde a una de las fechas faltantes.

# %%
# index = data_hourly.index
# data_hourly["hora"] = index.hour
# data_hourly["dia_mes"] = index.day
# data_hourly["dia_año"] = index.dayofyear 
# data_hourly["semana"] = index.week
# data_hourly["mes"] = index.month
data_hourly["faltante"] = data_hourly.index.map(lambda x: x in missing_dates)
data_hourly.head()
# Out:
#                      temp   hum  presion dir   vel  nub  prec  t_max  t_min  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0   1016.3   E  14.8  6.0   0.0   28.9   18.7
# 2019-04-01 01:00:00  19.2  93.0   1016.7   E   9.4  4.0   0.0   20.1   12.5
# 2019-04-01 02:00:00  18.5  95.0   1016.7   E   3.6  0.0   0.0   20.1   12.5
# 2019-04-01 03:00:00  15.2  96.0   1016.7   S   5.4  0.0   0.0   20.1   12.5
# 2019-04-01 04:00:00  16.2  95.0   1016.3   E   7.6  4.0   0.0   20.1   12.5
#
#                                     situacion faltante
# fecha
# 2019-04-01 00:00:00                    Nuboso    False
# 2019-04-01 01:00:00           Nubes dispersas    False
# 2019-04-01 02:00:00                 Despejado    False
# 2019-04-01 03:00:00        Despejado, neblina    False
# 2019-04-01 04:00:00  Nubes dispersas, neblina    False

# %% [markdown]
# Podemos crear una gráfica para ver como se distribuyen las fechas faltantes.

# %%
tmp = data_hourly.groupby(data_hourly.index.date)["faltante"].sum()
tmp = tmp[tmp != 0]
tmp.plot(kind="bar")

# %% [markdown]
# Los días 2019-06-16 y 2019-06-17 son los que registran un mayor número de valores faltantes. Si graficamos algunas de las series temporales...

# %%
f, ax = plt.subplots(4, 1, figsize=(16,12))
data_hourly.temp.plot(xlim=("2019-06", "2019-07"), ax=ax[0])
data_hourly.hum.plot(xlim=("2019-06", "2019-07"), ax=ax[1])
data_hourly.presion.plot(xlim=("2019-06", "2019-07"), ax=ax[2])
data_hourly.vel.plot(xlim=("2019-06", "2019-07"), ax=ax[3])

# %% [markdown]
# ...queda claro que esos valores faltantes son consecutivos. También parece que el intervalo entre el día 11 y 20 de junio presenta un patrón diferente al resto del mes. En particular, las oscilaciones diarias de temperatura y humedad disminuyen notablemente. Eso es extraño, y sumado a la gran cantidad de observaciones faltantes, podría indicar un problema con las mediciones de ese período.

# %% [markdown]
# Vamos a revisar las series de temperatura y humedad para cada uno de los meses por separado.

# %%
f, ax = plt.subplots(nrows=5, ncols=2, figsize=(16,16))
dates = pd.date_range(start="2019-04", end="2019-09", freq="MS")
for k in range(len(dates)-1):
    data_hourly.temp.plot(kind="line", xlim=(dates[k], dates[k+1]), ax=ax[k,0], ylim=(0,50));
    data_hourly.hum.plot(kind="line", xlim=(dates[k], dates[k+1]), ax=ax[k,1], ylim=(0,200));

# %%
data_hourly.isna().sum()
# Out:
# temp         77
# hum          83
# presion      78
# dir          73
# vel          73
# nub          73
# prec         73
# t_max        80
# t_min        80
# situacion    73
# faltante      0
# dtype: int64

# %% [markdown]
# ## Pronóstico

# %%
potencia = pd.read_csv("../data/potencia.csv", parse_dates=["fecha"], index_col="fecha")

# %%
potencia.head()
# Out:
#                      potencia
# fecha
# 2019-05-30 12:45:00       975
# 2019-05-30 12:46:00      1003
# 2019-05-30 12:47:00      1007
# 2019-05-30 12:48:00       989
# 2019-05-30 12:49:00       800

# %%
potencia = potencia.rename(columns={"potencia":"y"})

# %%
data = potencia.resample("H").mean()

# %%
data.plot()

# %%
#potencia_h["hora"] = potencia_h.index.hour
data["gen"] = (data.index.hour.isin(range(8,18))).astype("int64")

# %%
data.head()
# Out:
#                               y  gen
# fecha
# 2019-05-30 12:00:00  866.133333    1
# 2019-05-30 13:00:00  732.900000    1
# 2019-05-30 14:00:00  455.018868    1
# 2019-05-30 15:00:00  191.666667    1
# 2019-05-30 16:00:00   60.366667    1

# %%
dummy = pd.DataFrame()
dummy["sky1"] = (data_hourly.nub.isin([2,3]))
dummy["sky2"] = (data_hourly.nub.isin([4,5]))
dummy["sky3"] = (data_hourly.nub.isin([5,6]))
dummy["sky4"] = (data_hourly.nub.isin([7,8,9]))

# %%
dummy = dummy.astype("int64")

# %%
data = data.merge(dummy, right_index=True, left_index=True)

# %%
data.index.name = "ds"

# %%
data_hourly.tail(10)
# Out:
#                      temp   hum  presion dir   vel  nub  prec  t_max  t_min  \
# fecha
# 2019-09-04 10:00:00  -1.0  95.0   1028.4  SW  20.5  0.0   0.0    5.2   -2.1
# 2019-09-04 11:00:00  -1.6  95.0   1028.9  SW  20.5  1.0   0.0    5.2   -2.1
# 2019-09-04 12:00:00   1.1  77.0   1029.8   S  24.1  1.0   0.0    5.2   -2.1
# 2019-09-04 13:00:00   4.7  73.0   1030.5  SW  27.7  1.0   0.0    NaN    NaN
# 2019-09-04 14:00:00   6.9  57.0   1031.1   S  27.7  2.0   0.0    NaN    NaN
# 2019-09-04 15:00:00   8.6  42.0   1031.0   S  33.5  3.0   0.0    NaN    NaN
# 2019-09-04 16:00:00   8.6  39.0   1031.0   S  25.9  6.0   0.0    NaN    NaN
# 2019-09-04 17:00:00   8.7  33.0   1030.9   S  29.5  8.0   0.0    NaN    NaN
# 2019-09-04 18:00:00   7.7  41.0   1030.9   S  27.7  7.0   0.0    NaN    NaN
# 2019-09-04 19:00:00   8.2  46.0   1030.8   S  24.1  7.0   0.0    NaN    NaN
#
#                                               situacion faltante   sky1  \
# fecha
# 2019-09-04 10:00:00                  Despejado, neblina    False  False
# 2019-09-04 11:00:00              Algunas nubes, neblina    False  False
# 2019-09-04 12:00:00                       Algunas nubes    False  False
# 2019-09-04 13:00:00                       Algunas nubes    False  False
# 2019-09-04 14:00:00                       Algunas nubes    False   True
# 2019-09-04 15:00:00                     Nubes dispersas    False   True
# 2019-09-04 16:00:00                              Nuboso    False  False
# 2019-09-04 17:00:00  Cubierto, precipitación a la vista    False  False
# 2019-09-04 18:00:00                              Nuboso    False  False
# 2019-09-04 19:00:00                              Nuboso    False  False
#
#                       sky2   sky3   sky4
# fecha
# 2019-09-04 10:00:00  False  False  False
# 2019-09-04 11:00:00  False  False  False
# 2019-09-04 12:00:00  False  False  False
# 2019-09-04 13:00:00  False  False  False
# 2019-09-04 14:00:00  False  False  False
# 2019-09-04 15:00:00  False  False  False
# 2019-09-04 16:00:00  False   True  False
# 2019-09-04 17:00:00  False  False   True
# 2019-09-04 18:00:00  False  False   True
# 2019-09-04 19:00:00  False  False   True

# %%
data.tail(10)
# Out:
#                               y  gen  sky1  sky2  sky3  sky4
# ds
# 2019-09-04 10:00:00  811.266667    1     0     0     0     0
# 2019-09-04 11:00:00  951.766667    1     0     0     0     0
# 2019-09-04 12:00:00  839.033898    1     0     0     0     0
# 2019-09-04 13:00:00  451.333333    1     0     0     0     0
# 2019-09-04 14:00:00  632.366667    1     1     0     0     0
# 2019-09-04 15:00:00  514.733333    1     1     0     0     0
# 2019-09-04 16:00:00  251.050000    1     0     0     1     0
# 2019-09-04 17:00:00   85.779661    1     0     0     0     1
# 2019-09-04 18:00:00    4.150000    0     0     0     0     1
# 2019-09-04 19:00:00    0.000000    0     0     0     0     1

# %%
train = data.loc["2019-07":"2019-07-31"].copy()
test = data.loc["2019-08":"2019-08-07"].copy()

# %%
train.y.plot()

# %%
df = train.copy()

# %%
train.loc["2019-07-11 00:00:00":"2019-07-12 07:00:00", :] = train.loc["2019-07-09 00:00:00":"2019-07-10 07:00:00", :].to_numpy()

# %%
train.loc["2019-07-16 18:00:00":"2019-07-17 12:00:00", :] = train.loc["2019-07-15 18:00:00":"2019-07-16 12:00:00", :].to_numpy()

# %%
train.y.plot()

# %%
train.loc[:, "y"] = train.y.interpolate()

# %%
train.y.plot()

# %%
exog = ['gen', 'sky1', 'sky2', 'sky3', 'sky4']

# %%
train[exog] = train[exog].copy().astype("int64")

# %%
train.plot()

# %%
train.y.diff(periods=24).diff(periods=1).diff().dropna().plot()

# %%
model_arima = pmd.auto_arima(train["y"], exogenous=train[exog], D=1, d=2, m=24, seasonal=True, trace=True, suppress_warnings=True)
# Out:
# Fit ARIMA: order=(2, 2, 2) seasonal_order=(1, 1, 1, 24); AIC=8418.112, BIC=8477.606, Fit time=71.647 seconds
# Fit ARIMA: order=(0, 2, 0) seasonal_order=(0, 1, 0, 24); AIC=9172.287, BIC=9204.322, Fit time=0.668 seconds
# Fit ARIMA: order=(1, 2, 0) seasonal_order=(1, 1, 0, 24); AIC=8882.868, BIC=8924.056, Fit time=36.220 seconds
# Fit ARIMA: order=(0, 2, 1) seasonal_order=(0, 1, 1, 24); AIC=8435.217, BIC=8476.405, Fit time=26.070 seconds
# Fit ARIMA: order=(2, 2, 2) seasonal_order=(0, 1, 1, 24); AIC=8415.681, BIC=8470.599, Fit time=38.507 seconds
# Fit ARIMA: order=(2, 2, 2) seasonal_order=(0, 1, 0, 24); AIC=8796.297, BIC=8846.638, Fit time=10.127 seconds
# Fit ARIMA: order=(2, 2, 2) seasonal_order=(0, 1, 2, 24); AIC=8417.319, BIC=8476.813, Fit time=91.853 seconds
# Fit ARIMA: order=(2, 2, 2) seasonal_order=(1, 1, 2, 24); AIC=8419.722, BIC=8483.793, Fit time=96.487 seconds
# Fit ARIMA: order=(1, 2, 2) seasonal_order=(0, 1, 1, 24); AIC=8408.952, BIC=8459.293, Fit time=31.541 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(0, 1, 1, 24); AIC=8412.151, BIC=8457.916, Fit time=33.511 seconds
# Fit ARIMA: order=(1, 2, 3) seasonal_order=(0, 1, 1, 24); AIC=8405.464, BIC=8460.382, Fit time=35.459 seconds
# Fit ARIMA: order=(0, 2, 2) seasonal_order=(0, 1, 1, 24); AIC=8401.018, BIC=8446.783, Fit time=30.499 seconds
# Fit ARIMA: order=(0, 2, 2) seasonal_order=(1, 1, 1, 24); AIC=8403.517, BIC=8453.858, Fit time=32.444 seconds
# Fit ARIMA: order=(0, 2, 2) seasonal_order=(0, 1, 0, 24); AIC=8796.584, BIC=8837.773, Fit time=5.380 seconds
# Fit ARIMA: order=(0, 2, 2) seasonal_order=(0, 1, 2, 24); AIC=8403.916, BIC=8454.257, Fit time=80.533 seconds
# Fit ARIMA: order=(0, 2, 2) seasonal_order=(1, 1, 2, 24); AIC=8404.055, BIC=8458.972, Fit time=86.077 seconds
# Fit ARIMA: order=(0, 2, 3) seasonal_order=(0, 1, 1, 24); AIC=8395.418, BIC=8445.759, Fit time=27.438 seconds
# Fit ARIMA: order=(1, 2, 4) seasonal_order=(0, 1, 1, 24); AIC=8398.488, BIC=8457.982, Fit time=37.827 seconds
# Fit ARIMA: order=(0, 2, 3) seasonal_order=(1, 1, 1, 24); AIC=8399.715, BIC=8454.633, Fit time=43.602 seconds
# Fit ARIMA: order=(0, 2, 3) seasonal_order=(0, 1, 0, 24); AIC=8790.234, BIC=8835.999, Fit time=5.640 seconds
# Fit ARIMA: order=(0, 2, 3) seasonal_order=(0, 1, 2, 24); AIC=8415.031, BIC=8469.949, Fit time=48.844 seconds
# Fit ARIMA: order=(0, 2, 3) seasonal_order=(1, 1, 2, 24); AIC=8398.827, BIC=8458.321, Fit time=87.724 seconds
# Fit ARIMA: order=(0, 2, 4) seasonal_order=(0, 1, 1, 24); AIC=8393.598, BIC=8448.515, Fit time=53.897 seconds
# Fit ARIMA: order=(1, 2, 5) seasonal_order=(0, 1, 1, 24); AIC=8389.102, BIC=8453.173, Fit time=42.565 seconds
# Fit ARIMA: order=(1, 2, 5) seasonal_order=(1, 1, 1, 24); AIC=8397.505, BIC=8466.152, Fit time=48.433 seconds
# Fit ARIMA: order=(1, 2, 5) seasonal_order=(0, 1, 0, 24); AIC=8770.516, BIC=8830.010, Fit time=11.258 seconds
# Fit ARIMA: order=(1, 2, 5) seasonal_order=(0, 1, 2, 24); AIC=8408.023, BIC=8476.670, Fit time=87.421 seconds
# Fit ARIMA: order=(1, 2, 5) seasonal_order=(1, 1, 2, 24); AIC=8395.207, BIC=8468.431, Fit time=111.609 seconds
# Fit ARIMA: order=(0, 2, 5) seasonal_order=(0, 1, 1, 24); AIC=8391.240, BIC=8450.734, Fit time=55.678 seconds
# Fit ARIMA: order=(2, 2, 5) seasonal_order=(0, 1, 1, 24); AIC=8408.630, BIC=8477.277, Fit time=48.561 seconds
# Total fit time: 1417.697 seconds

# %%
forecast = model_arima.predict(n_periods=len(test), exogenous=test[exog])

# %%
forecast = pd.Series(forecast, index=test.index)

# %%
test.y.plot()
forecast.plot()

# %%
train_range = pd.date_range(start="2019-07-01", end="2019-07-31", freq="H")
test_range = pd.date_range(start="2019-08-01", end="2019-08-08", freq="H")
train = df.loc[df.ds.isin(train_range), :].copy()
test = df.loc[df.ds.isin(test_range), :].copy()

# %%
model_prophet = Prophet(yearly_seasonality=False, weekly_seasonality=False, daily_seasonality=True)

# %%
model_prophet.add_regressor("sky1")
model_prophet.add_regressor("sky2")
model_prophet.add_regressor("sky3")
model_prophet.add_regressor("sky4")
model_prophet.add_regressor("gen")

# %%
model_prophet.fit(train)

# %%
future = model_prophet.make_future_dataframe(periods=len(test), freq="H")

# %%
future
# Out:
#                      ds
# 0   2019-07-01 00:00:00
# 1   2019-07-01 01:00:00
# 2   2019-07-01 02:00:00
# 3   2019-07-01 03:00:00
# 4   2019-07-01 04:00:00
# ..                  ...
# 885 2019-08-06 21:00:00
# 886 2019-08-06 22:00:00
# 887 2019-08-06 23:00:00
# 888 2019-08-07 00:00:00
# 889 2019-08-07 01:00:00
#
# [890 rows x 1 columns]

# %%
exog = ["ds", "gen", "sky1", "sky2", "sky3", "sky4"]
future = future.merge(df.loc[:, exog], left_on="ds", right_on="ds")

# %%
future
# Out:
#                      ds  gen  sky1  sky2  sky3  sky4
# 0   2019-07-01 00:00:00    0     0     0     0     0
# 1   2019-07-01 01:00:00    0     0     0     0     0
# 2   2019-07-01 02:00:00    0     0     0     0     0
# 3   2019-07-01 03:00:00    0     0     0     0     0
# 4   2019-07-01 04:00:00    0     0     0     0     0
# ..                  ...  ...   ...   ...   ...   ...
# 885 2019-08-06 21:00:00    0     0     0     0     0
# 886 2019-08-06 22:00:00    0     0     0     0     0
# 887 2019-08-06 23:00:00    0     0     0     0     0
# 888 2019-08-07 00:00:00    0     0     0     0     0
# 889 2019-08-07 01:00:00    0     0     0     0     0
#
# [890 rows x 6 columns]

# %%
forecast = model_prophet.predict(future)

# %%
model_prophet.plot(forecast);

# %%
#yhat = pd.Series(forecast.yhat, index=df.set_index("ds").index)
forecast.set_index("ds").yhat.plot()
test.set_index("ds").y.plot()
train.set_index("ds").y.plot()

# %%
mask = (df.sky1 == 0) & (df.sky2 == 0) & (df.sky3 == 0) & (df.sky4 == 0)

# %%
df.loc[(mask), "y"].plot()

# %%
forecast
# Out:
#                      ds       trend  yhat_lower  yhat_upper  trend_lower  \
# 0   2019-07-01 00:00:00  211.885702 -284.972100   55.971017   211.885702
# 1   2019-07-01 01:00:00  211.912856 -285.585699   36.949285   211.912856
# 2   2019-07-01 02:00:00  211.940011 -273.885326   47.018098   211.940011
# 3   2019-07-01 03:00:00  211.967165 -253.386988   78.896738   211.967165
# 4   2019-07-01 04:00:00  211.994319 -143.320635  185.500675   211.994319
# ..                  ...         ...         ...         ...          ...
# 885 2019-08-06 21:00:00  179.662571 -144.110283  180.720455   177.859278
# 886 2019-08-06 22:00:00  179.578159 -136.910889  187.927063   177.764996
# 887 2019-08-06 23:00:00  179.493748 -160.433943  175.303048   177.663620
# 888 2019-08-07 00:00:00  179.409336 -178.420514  148.422720   177.560691
# 889 2019-08-07 01:00:00  179.324925 -173.135084  152.410822   177.453252
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0     211.885702     -327.031826           -327.031826           -327.031826
# 1     211.912856     -330.828841           -330.828841           -330.828841
# 2     211.940011     -319.405518           -319.405518           -319.405518
# 3     211.967165     -304.435777           -304.435777           -304.435777
# 4     211.994319     -193.195702           -193.195702           -193.195702
# ..           ...             ...                   ...                   ...
# 885   181.255459     -156.227273           -156.227273           -156.227273
# 886   181.191308     -158.655790           -158.655790           -158.655790
# 887   181.121466     -174.827299           -174.827299           -174.827299
# 888   181.049844     -191.627871           -191.627871           -191.627871
# 889   180.978143     -195.424885           -195.424885           -195.424885
#
#           daily  ...       sky3  sky3_lower  sky3_upper        sky4  \
# 0   -191.627871  ...   0.000000    0.000000    0.000000 -135.403955
# 1   -195.424885  ...   0.000000    0.000000    0.000000 -135.403955
# 2   -184.001563  ...   0.000000    0.000000    0.000000 -135.403955
# 3   -169.031822  ...   0.000000    0.000000    0.000000 -135.403955
# 4   -166.142990  ... -27.052712  -27.052712  -27.052712    0.000000
# ..          ...  ...        ...         ...         ...         ...
# 885 -156.227273  ...   0.000000    0.000000    0.000000    0.000000
# 886 -158.655790  ...   0.000000    0.000000    0.000000    0.000000
# 887 -174.827299  ...   0.000000    0.000000    0.000000    0.000000
# 888 -191.627871  ...   0.000000    0.000000    0.000000    0.000000
# 889 -195.424885  ...   0.000000    0.000000    0.000000    0.000000
#
#      sky4_lower  sky4_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0   -135.403955 -135.403955                   0.0                         0.0
# 1   -135.403955 -135.403955                   0.0                         0.0
# 2   -135.403955 -135.403955                   0.0                         0.0
# 3   -135.403955 -135.403955                   0.0                         0.0
# 4      0.000000    0.000000                   0.0                         0.0
# ..          ...         ...                   ...                         ...
# 885    0.000000    0.000000                   0.0                         0.0
# 886    0.000000    0.000000                   0.0                         0.0
# 887    0.000000    0.000000                   0.0                         0.0
# 888    0.000000    0.000000                   0.0                         0.0
# 889    0.000000    0.000000                   0.0                         0.0
#
#      multiplicative_terms_upper        yhat
# 0                           0.0 -115.146124
# 1                           0.0 -118.915984
# 2                           0.0 -107.465507
# 3                           0.0  -92.468612
# 4                           0.0   18.798617
# ..                          ...         ...
# 885                         0.0   23.435298
# 886                         0.0   20.922369
# 887                         0.0    4.666449
# 888                         0.0  -12.218534
# 889                         0.0  -16.099961
#
# [890 rows x 31 columns]

# %%
df.y.plot().

# %%
train.y.plot()

# %%
test.y.plot()

# %%
train.loc["2019-07-01":"2019-07-02"]
# Out:
#                             pot
# fecha
# 2019-07-01 00:00:00    0.000000
# 2019-07-01 01:00:00    0.000000
# 2019-07-01 02:00:00    0.000000
# 2019-07-01 03:00:00    0.000000
# 2019-07-01 04:00:00    0.000000
# 2019-07-01 05:00:00    0.000000
# 2019-07-01 06:00:00    0.000000
# 2019-07-01 07:00:00    0.000000
# 2019-07-01 08:00:00   98.830508
# 2019-07-01 09:00:00  414.416667
# 2019-07-01 10:00:00  693.100000
# 2019-07-01 11:00:00  885.500000
# 2019-07-01 12:00:00  927.850000
# 2019-07-01 13:00:00  735.983051
# 2019-07-01 14:00:00  634.016667
# 2019-07-01 15:00:00  545.633333
# 2019-07-01 16:00:00  339.750000
# 2019-07-01 17:00:00   74.300000
# 2019-07-01 18:00:00    0.000000
# 2019-07-01 19:00:00    0.000000
# 2019-07-01 20:00:00    0.000000
# 2019-07-01 21:00:00    0.000000
# 2019-07-01 22:00:00    0.000000
# 2019-07-01 23:00:00    0.000000
# 2019-07-02 00:00:00    0.000000
# 2019-07-02 01:00:00    0.000000
# 2019-07-02 02:00:00    0.000000
# 2019-07-02 03:00:00    0.000000
# 2019-07-02 04:00:00    0.000000
# 2019-07-02 05:00:00    0.000000
# 2019-07-02 06:00:00    0.000000
# 2019-07-02 07:00:00    0.000000
# 2019-07-02 08:00:00    5.483333
# 2019-07-02 09:00:00  172.728814
# 2019-07-02 10:00:00  670.166667
# 2019-07-02 11:00:00  875.483333
# 2019-07-02 12:00:00  980.533333
# 2019-07-02 13:00:00  953.566667
# 2019-07-02 14:00:00  827.457627
# 2019-07-02 15:00:00  556.366667
# 2019-07-02 16:00:00  318.466667
# 2019-07-02 17:00:00   33.366667
# 2019-07-02 18:00:00    0.000000
# 2019-07-02 19:00:00    0.000000
# 2019-07-02 20:00:00    0.000000
# 2019-07-02 21:00:00    0.000000
# 2019-07-02 22:00:00    0.000000
# 2019-07-02 23:00:00    0.000000

# %%
data_hourly["hora"] = data_hourly.index.hour

# %%
data_hourly["generating"] = (data_hourly.hora.isin(range(8,18)))

# %%
data_hourly.head(30)
# Out:
#                      temp   hum  presion  dir   vel  nub  prec  t_max  t_min  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0   1016.3    E  14.8  6.0   0.0   28.9   18.7
# 2019-04-01 01:00:00  19.2  93.0   1016.7    E   9.4  4.0   0.0   20.1   12.5
# 2019-04-01 02:00:00  18.5  95.0   1016.7    E   3.6  0.0   0.0   20.1   12.5
# 2019-04-01 03:00:00  15.2  96.0   1016.7    S   5.4  0.0   0.0   20.1   12.5
# 2019-04-01 04:00:00  16.2  95.0   1016.3    E   7.6  4.0   0.0   20.1   12.5
# 2019-04-01 05:00:00  16.0  96.0   1016.6    -   0.0  4.0   0.0   20.1   12.5
# 2019-04-01 06:00:00  15.6  96.0   1015.8    -   0.0  5.0   0.0   20.1   12.5
# 2019-04-01 07:00:00  15.2  96.0   1015.2    E   5.4  7.0   0.0   20.1   12.5
# 2019-04-01 08:00:00  15.0  95.0   1014.9   SE   5.4  6.0   0.0   20.1   12.5
# 2019-04-01 09:00:00  13.6  98.0   1015.7    S   5.4  3.0   0.0   20.1   12.5
# 2019-04-01 10:00:00  13.5  98.0   1016.1    E   5.4  5.0   0.0   20.1   12.5
# 2019-04-01 11:00:00  13.4  97.0   1016.6    E   7.6  4.0   0.0   20.1   12.5
# 2019-04-01 12:00:00  17.2  98.0   1017.4   SE   1.8  4.0   0.0   20.1   12.5
# 2019-04-01 13:00:00  20.4  73.0   1017.0    N  13.0  4.0   0.0   28.2   17.2
# 2019-04-01 14:00:00  22.8  56.0   1016.5    N  16.6  1.0   0.0   28.2   17.2
# 2019-04-01 15:00:00  24.7  50.0   1016.0    N  14.8  1.0   0.0   28.2   17.2
# 2019-04-01 16:00:00  26.2  47.0   1015.6    N  18.4  1.0   0.0   28.2   17.2
# 2019-04-01 17:00:00  27.0  45.0   1014.6    N  22.3  1.0   0.0   28.2   17.2
# 2019-04-01 18:00:00  27.2  40.0   1013.8    N  20.5  1.0   0.0   28.2   17.2
# 2019-04-01 19:00:00  26.6  47.0   1013.5    N  18.4  4.0   0.0   28.2   17.2
# 2019-04-01 20:00:00  27.0  48.0   1013.4    N  18.4  5.0   0.0   28.2   17.2
# 2019-04-01 21:00:00  25.2  58.0   1013.5    N  14.8  5.0   0.0   28.2   17.2
# 2019-04-01 22:00:00  21.0  77.0   1013.0    N  13.0  3.0   0.0   28.2   17.2
# 2019-04-01 23:00:00  19.3  86.0   1013.2    N  11.2  2.0   0.0   28.2   17.2
# 2019-04-02 00:00:00  19.2  85.0   1012.7    N  11.1  2.0   0.0   28.2   17.2
# 2019-04-02 01:00:00  18.4  93.0   1013.0    N   7.6  1.0   0.0   19.2   15.0
# 2019-04-02 02:00:00  17.2  93.0   1012.8    -   0.0  0.0   0.0   19.2   15.0
# 2019-04-02 03:00:00  16.7  95.0   1012.2    N  11.2  0.0   0.0   19.2   15.0
# 2019-04-02 04:00:00   NaN   NaN      NaN  NaN   NaN  NaN   NaN    NaN    NaN
# 2019-04-02 05:00:00  16.5  93.0   1011.2   NW   5.4  0.0   0.0   19.2   15.0
#
#                                                    situacion faltante   sky1  \
# fecha
# 2019-04-01 00:00:00                                   Nuboso    False  False
# 2019-04-01 01:00:00                          Nubes dispersas    False  False
# 2019-04-01 02:00:00                                Despejado    False  False
# 2019-04-01 03:00:00                       Despejado, neblina    False  False
# 2019-04-01 04:00:00                 Nubes dispersas, neblina    False  False
# 2019-04-01 05:00:00                 Nubes dispersas, neblina    False  False
# 2019-04-01 06:00:00                          Nuboso, neblina    False  False
# 2019-04-01 07:00:00                          Nuboso, neblina    False  False
# 2019-04-01 08:00:00                          Nuboso, neblina    False  False
# 2019-04-01 09:00:00                 Nubes dispersas, neblina    False   True
# 2019-04-01 10:00:00                          Nuboso, neblina    False  False
# 2019-04-01 11:00:00                  Nubes dispersas, niebla    False  False
# 2019-04-01 12:00:00  Nubes dispersas, niebla o niebla helada    False  False
# 2019-04-01 13:00:00                          Nubes dispersas    False  False
# 2019-04-01 14:00:00                            Algunas nubes    False  False
# 2019-04-01 15:00:00                            Algunas nubes    False  False
# 2019-04-01 16:00:00                            Algunas nubes    False  False
# 2019-04-01 17:00:00                            Algunas nubes    False  False
# 2019-04-01 18:00:00                            Algunas nubes    False  False
# 2019-04-01 19:00:00                          Nubes dispersas    False  False
# 2019-04-01 20:00:00                                   Nuboso    False  False
# 2019-04-01 21:00:00                                   Nuboso    False  False
# 2019-04-01 22:00:00                          Nubes dispersas    False   True
# 2019-04-01 23:00:00                            Algunas nubes    False   True
# 2019-04-02 00:00:00                            Algunas nubes    False   True
# 2019-04-02 01:00:00                            Algunas nubes    False  False
# 2019-04-02 02:00:00                                Despejado    False  False
# 2019-04-02 03:00:00                                Despejado    False  False
# 2019-04-02 04:00:00                                      NaN     True  False
# 2019-04-02 05:00:00                                Despejado    False  False
#
#                       sky2   sky3   sky4   sky5  hora  generating
# fecha
# 2019-04-01 00:00:00  False   True  False  False     0       False
# 2019-04-01 01:00:00   True  False  False  False     1       False
# 2019-04-01 02:00:00  False  False  False  False     2       False
# 2019-04-01 03:00:00  False  False  False  False     3       False
# 2019-04-01 04:00:00   True  False  False  False     4       False
# 2019-04-01 05:00:00   True  False  False  False     5       False
# 2019-04-01 06:00:00   True   True  False  False     6       False
# 2019-04-01 07:00:00  False  False   True  False     7       False
# 2019-04-01 08:00:00  False   True  False  False     8        True
# 2019-04-01 09:00:00  False  False  False  False     9        True
# 2019-04-01 10:00:00   True   True  False  False    10        True
# 2019-04-01 11:00:00   True  False  False  False    11        True
# 2019-04-01 12:00:00   True  False  False  False    12        True
# 2019-04-01 13:00:00   True  False  False  False    13        True
# 2019-04-01 14:00:00  False  False  False  False    14        True
# 2019-04-01 15:00:00  False  False  False  False    15        True
# 2019-04-01 16:00:00  False  False  False  False    16        True
# 2019-04-01 17:00:00  False  False  False  False    17        True
# 2019-04-01 18:00:00  False  False  False  False    18       False
# 2019-04-01 19:00:00   True  False  False  False    19       False
# 2019-04-01 20:00:00   True   True  False  False    20       False
# 2019-04-01 21:00:00   True   True  False  False    21       False
# 2019-04-01 22:00:00  False  False  False  False    22       False
# 2019-04-01 23:00:00  False  False  False  False    23       False
# 2019-04-02 00:00:00  False  False  False  False     0       False
# 2019-04-02 01:00:00  False  False  False  False     1       False
# 2019-04-02 02:00:00  False  False  False  False     2       False
# 2019-04-02 03:00:00  False  False  False  False     3       False
# 2019-04-02 04:00:00  False  False  False  False     4       False
# 2019-04-02 05:00:00  False  False  False  False     5       False

# %%
(data_hourly.nub == 0)
# Out:
# fecha
# 2019-04-01 00:00:00    False
# 2019-04-01 01:00:00    False
# 2019-04-01 02:00:00     True
# 2019-04-01 03:00:00     True
# 2019-04-01 04:00:00    False
#                        ...
# 2019-09-04 15:00:00    False
# 2019-09-04 16:00:00    False
# 2019-09-04 17:00:00    False
# 2019-09-04 18:00:00    False
# 2019-09-04 19:00:00    False
# Freq: H, Name: nub, Length: 3764, dtype: bool

# %%
potencia_h.index
# Out:
# DatetimeIndex(['2019-05-30 12:00:00', '2019-05-30 13:00:00',
#                '2019-05-30 14:00:00', '2019-05-30 15:00:00',
#                '2019-05-30 16:00:00', '2019-05-30 17:00:00',
#                '2019-05-30 18:00:00', '2019-05-30 19:00:00',
#                '2019-05-30 20:00:00', '2019-05-30 21:00:00',
#                ...
#                '2019-09-30 08:00:00', '2019-09-30 09:00:00',
#                '2019-09-30 10:00:00', '2019-09-30 11:00:00',
#                '2019-09-30 12:00:00', '2019-09-30 13:00:00',
#                '2019-09-30 14:00:00', '2019-09-30 15:00:00',
#                '2019-09-30 16:00:00', '2019-09-30 17:00:00'],
#               dtype='datetime64[ns]', name='fecha', length=2958, freq='H')

# %%
potencia_h = potencia_h.merge(data_hourly.nub, left_index=True, right_index=True)

# %%
potencia_h.pot.plot()

# %%
potencia_h[potencia_h.nub == 0]

# %%
potencia_h[potencia_h.nub == 5].pot.plot()

# %%
#clear_sky = data_hourly.loc[(data_hourly.nub == 0) & (data_hourly.index.month.isin([6,7,8,9]))]
clear_sky = (data_hourly.nub == 0) 
clear_sky[potencia_h.index].dropna()
potencia_h[clear_sky]
# Out:
# C:\Users\ariel\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-80-5d91c866705e> in <module>
#       2 clear_sky = (data_hourly.nub == 0)
#       3 clear_sky[potencia_h.index].dropna()
# ----> 4 potencia_h[clear_sky]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2969         # Do we have a (boolean) 1d indexer?
#    2970         if com.is_bool_indexer(key):
# -> 2971             return self._getitem_bool_array(key)
#    2972
#    2973         # We are left with two options: a single key, and a collection of keys,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3021         # check_bool_indexer will throw exception if Series key cannot
#    3022         # be reindexed to match DataFrame rows
# -> 3023         key = check_bool_indexer(self.index, key)
#    3024         indexer = key.nonzero()[0]
#    3025         return self.take(indexer, axis=0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2409         if mask.any():
#    2410             raise IndexingError(
# -> 2411                 "Unalignable boolean Series provided as "
#    2412                 "indexer (index of the boolean Series and of "
#    2413                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
potencia_h.plot()

# %%
train.loc[:,"dia"] = train.index.day
train.loc[:,"hora"] = train.index.hour

# %%
train.loc[train.dia.isin([10,11,12]), "pot"].plot()

# %%
train.loc[train.dia.isin([16,17]), "pot"].plot()

# %%
values = train.loc[train.dia == 9, "pot"].to_numpy()
train.loc[train.dia == 11, "pot"] = values

# %%
train.loc[(train.dia == 12) & (train.hora.isin(range(0,8))), "pot"] = 0
train.loc[(train.dia == 17) & (train.hora.isin(range(0,8))), "pot"] = 0
train.loc[(train.dia == 16) & (train.hora.isin(range(18,24))), "pot"] = 0

# %%
train.loc[:, "pot"] = train.loc[:,"pot"].interpolate(method="spline", order=2)

# %%
train.pot.plot()

# %%
train = train.drop(columns=["dia", "hora"])

# %%
regressors = ["temp", "hum", "presion", "sky1", "sky2", "sky3", "sky4", "sky5"]
exog_train = data_hourly.loc["2019-07-01":"2019-07-31", regressors].copy()
exog_test = data_hourly.loc["2019-08-01":"2019-08-07", regressors].copy()

# %%
exog_train
# Out:
#                      temp   hum  presion   sky1   sky2   sky3   sky4   sky5
# fecha
# 2019-07-01 00:00:00   4.2  93.0   1020.4  False  False  False  False  False
# 2019-07-01 01:00:00   3.7  86.0   1020.6  False  False  False  False  False
# 2019-07-01 02:00:00   2.9  87.0   1020.9  False  False  False  False  False
# 2019-07-01 03:00:00   1.5  96.0   1021.2  False  False  False  False  False
# 2019-07-01 04:00:00   0.9  96.0   1021.1  False  False  False  False  False
# ...                   ...   ...      ...    ...    ...    ...    ...    ...
# 2019-07-31 19:00:00  14.2  69.0   1006.0  False  False  False   True  False
# 2019-07-31 20:00:00  13.4  77.0   1005.9  False  False  False   True  False
# 2019-07-31 21:00:00  12.4  76.0   1006.9  False  False  False   True  False
# 2019-07-31 22:00:00  10.8  82.0   1007.7  False  False  False   True  False
# 2019-07-31 23:00:00  10.7  76.0   1008.4  False  False   True  False  False
#
# [744 rows x 8 columns]

# %%
exog_train["dia"] = exog_train.index.day
exog_train["hora"] = exog_train.index.hour

# %%
exog_train.temp.plot()

# %%
exog_train.loc[exog_train.dia == 9, "temp"].plot()

# %%
exog_train.loc[exog_train.dia == 16, "temp"].plot()

# %%
exog_train.loc[exog_train.dia == 24, "temp"].plot()

# %%
exog_train.loc[(exog_train.dia == 9) & (exog_train.hora == 17), "temp"] = np.nan
exog_train.loc[(exog_train.dia == 16) & (exog_train.hora == 7), "temp"] = np.nan
exog_train.loc[(exog_train.dia == 24) & (exog_train.hora == 10), "temp"] = np.nan

# %%
exog_train.loc[exog_train.dia == 16, "hum"].plot()

# %%
exog_train.loc[exog_train.dia == 24, "hum"].plot()

# %%
exog_train.loc[exog_train.dia.isin([30,31]), "hum"].plot()

# %%
exog_train.loc[(exog_train.dia == 16) & (exog_train.hora == 7), "hum"] = np.nan
exog_train.loc[(exog_train.dia == 24) & (exog_train.hora == 10), "hum"] = np.nan
exog_train.loc[(exog_train.dia == 30) & (exog_train.hora == 22), "hum"] = np.nan
exog_train.loc[(exog_train.dia == 30) & (exog_train.hora == 23), "hum"] = np.nan

# %%
values = exog_train.loc[:, ["temp", "hum", "presion"]].interpolate(method="linear")
exog_train.loc[:, ["temp", "hum", "presion"]] = values

# %%
exog_train = exog_train.drop(columns=["dia", "hora"])

# %%
exog_train.isna().sum()
# Out:
# temp       0
# hum        0
# presion    0
# sky1       0
# sky2       0
# sky3       0
# sky4       0
# sky5       0
# dtype: int64

# %%
cols = exog_train.columns
f, ax = plt.subplots(len(cols), 1, figsize=(16,12))
for k,col in enumerate(cols):
    exog_train[col].plot(ax=ax[k])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-f4cb884c36d5> in <module>
#       2 f, ax = plt.subplots(len(cols), 1, figsize=(16,12))
#       3 for k,col in enumerate(cols):
# ----> 4     exog_train[col].plot(ax=ax[k])
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     412         # no non-numeric frames or series allowed
#     413         if is_empty:
# --> 414             raise TypeError("no numeric data to plot")
#     415
#     416         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
cols = exog_test.columns
f, ax = plt.subplots(len(cols), 1, figsize=(16,12))
for k,col in enumerate(cols):
    exog_test[col].plot(ax=ax[k])

# %%
values = exog_test.loc[:, ["temp", "hum", "presion", "vel"]].interpolate(method="linear")
exog_test.loc[:, ["temp", "hum", "presion", "vel"]] = values
exog_test.nub = exog_test.nub.fillna(method="ffill")

# %%
exog_test.isna().sum()
# Out:
# temp       0
# hum        0
# presion    0
# vel        0
# nub        0
# dtype: int64

# %%
cols = exog_test.columns
f, ax = plt.subplots(len(cols), 1, figsize=(16,12))
for k,col in enumerate(cols):
    exog_test[col].plot(ax=ax[k])

# %% [markdown]
# ## ARIMA

# %%
fit_autoarima = pmd.auto_arima(train, exogenous=exog_train, seasonal=True, m=24, d=0, D=1, trace=True, suppress_warnings=True)
# Out:
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 1, 1, 24); AIC=8311.371, BIC=8370.902, Fit time=62.723 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 24); AIC=9552.826, BIC=9584.880, Fit time=0.609 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 24); AIC=8571.946, BIC=8613.159, Fit time=25.155 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 24); AIC=8612.019, BIC=8653.233, Fit time=26.263 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 1, 24); AIC=8308.775, BIC=8363.726, Fit time=34.485 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 0, 24); AIC=8723.239, BIC=8773.611, Fit time=8.001 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 2, 24); AIC=8310.752, BIC=8370.282, Fit time=78.716 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 1, 2, 24); AIC=8322.647, BIC=8386.756, Fit time=90.380 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 1, 1, 24); AIC=8311.629, BIC=8362.001, Fit time=35.363 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 1, 24); AIC=8314.461, BIC=8373.991, Fit time=38.835 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 24); AIC=8311.642, BIC=8362.014, Fit time=37.751 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 1, 1, 24); AIC=8323.697, BIC=8383.227, Fit time=45.587 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 24); AIC=8310.513, BIC=8356.306, Fit time=29.810 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 1, 1, 24); AIC=8323.645, BIC=8387.754, Fit time=41.640 seconds
# Total fit time: 555.466 seconds

# %%
forecast = fit_autoarima.predict(n_periods=24*7, exogenous=exog_test)
forecast = pd.Series(forecast, index=test.index)

# %%
train.pot.plot()
test.pot.plot()
forecast.plot()

# %%
in_sample = fit_autoarima.predict_in_sample(exogenous=exog_train, start=0, end=743)
in_sample = pd.Series(in_sample, index=train.index)

# %%
train.plot()
in_sample.plot()

# %% [markdown]
# ## Prophet

# %%
train_data = train.join(exog_train)
train_data = train_data.reset_index().rename(columns={"fecha":"ds", "pot":"y"})
train_data.head()
# Out:
#                    ds    y  temp   hum  presion   vel  nub
# 0 2019-07-01 00:00:00  0.0   4.2  93.0   1020.4  14.8  0.0
# 1 2019-07-01 01:00:00  0.0   3.7  86.0   1020.6  22.3  0.0
# 2 2019-07-01 02:00:00  0.0   2.9  87.0   1020.9  27.7  0.0
# 3 2019-07-01 03:00:00  0.0   1.5  96.0   1021.2  25.9  0.0
# 4 2019-07-01 04:00:00  0.0   0.9  96.0   1021.1  27.7  0.0

# %%
test_data = test.join(exog_test)
test_data = test_data.reset_index().rename(columns={"fecha":"ds", "pot":"y"})
test_data.tail()
# Out:
#                      ds    y  temp   hum  presion   vel  nub
# 163 2019-08-07 19:00:00  0.0  15.6  26.0   1022.6   0.0  2.0
# 164 2019-08-07 20:00:00  0.0  16.2  24.0   1022.8   0.0  1.0
# 165 2019-08-07 21:00:00  0.0  11.8  42.0   1023.5  11.2  3.0
# 166 2019-08-07 22:00:00  0.0  10.4  44.0   1024.2   3.6  2.0
# 167 2019-08-07 23:00:00  0.0   7.3  40.0   1024.8   5.4  0.0

# %%
model_prophet = Prophet(daily_seasonality=True, weekly_seasonality=False, yearly_seasonality=False, 
                        seasonality_mode="additive")

# %%
model_prophet.add_regressor("temp")
model_prophet.add_regressor("hum")
model_prophet.add_regressor("presion")
model_prophet.add_regressor("vel")
model_prophet.add_regressor("nub")

# %%
model_prophet.fit(train_data)

# %%
future = model_prophet.make_future_dataframe(24*7, freq="H", include_history=True)

# %%
exogs = pd.concat([train_data, test_data])
exogs = exogs.drop(columns="y")
exogs.head()
# Out:
#                    ds  temp   hum  presion   vel  nub
# 0 2019-07-01 00:00:00   4.2  93.0   1020.4  14.8  0.0
# 1 2019-07-01 01:00:00   3.7  86.0   1020.6  22.3  0.0
# 2 2019-07-01 02:00:00   2.9  87.0   1020.9  27.7  0.0
# 3 2019-07-01 03:00:00   1.5  96.0   1021.2  25.9  0.0
# 4 2019-07-01 04:00:00   0.9  96.0   1021.1  27.7  0.0

# %%
future = pd.merge(future, exogs, on="ds")

# %%
forecast = model_prophet.predict(future)

# %%
yhat = forecast[["ds", "yhat"]]
yhat.head()
# Out:
#                    ds       yhat
# 0 2019-07-01 00:00:00  21.621995
# 1 2019-07-01 01:00:00  37.275974
# 2 2019-07-01 02:00:00  49.653092
# 3 2019-07-01 03:00:00  46.740943
# 4 2019-07-01 04:00:00  49.597134

# %%
yhat = yhat.set_index("ds")

# %%
ax = train.plot()
test.plot(ax=ax)
yhat.plot(ax=ax)

# %%
model_prophet.plot(forecast);

# %% [markdown]
# ## Rolling forecast con Prophet

# %%
train_data = train.join(exog_train)
train_data = train_data.reset_index().rename(columns={"fecha":"ds", "pot":"y"})
train_data.head()
# Out:
#                    ds    y  temp   hum  presion   vel  nub
# 0 2019-07-01 00:00:00  0.0   4.2  93.0   1020.4  14.8  0.0
# 1 2019-07-01 01:00:00  0.0   3.7  86.0   1020.6  22.3  0.0
# 2 2019-07-01 02:00:00  0.0   2.9  87.0   1020.9  27.7  0.0
# 3 2019-07-01 03:00:00  0.0   1.5  96.0   1021.2  25.9  0.0
# 4 2019-07-01 04:00:00  0.0   0.9  96.0   1021.1  27.7  0.0

# %%
test_data = test.join(exog_test)
test_data = test_data.reset_index().rename(columns={"fecha":"ds", "pot":"y"})
test_data.tail()
# Out:
#                      ds    y  temp   hum  presion   vel  nub
# 163 2019-08-07 19:00:00  0.0  15.6  26.0   1022.6   0.0  2.0
# 164 2019-08-07 20:00:00  0.0  16.2  24.0   1022.8   0.0  1.0
# 165 2019-08-07 21:00:00  0.0  11.8  42.0   1023.5  11.2  3.0
# 166 2019-08-07 22:00:00  0.0  10.4  44.0   1024.2   3.6  2.0
# 167 2019-08-07 23:00:00  0.0   7.3  40.0   1024.8   5.4  0.0

# %%
model_prophet = Prophet(daily_seasonality=True, weekly_seasonality=False, yearly_seasonality=False)

# %%
model_prophet.fit(train_data)

# %%
#future_1h = model_prophet.make_future_dataframe(1, freq="H", include_history=False)
future_12h = model_prophet.make_future_dataframe(12, freq="H", include_history=False)

# %%
exogs_future = test_data.drop(columns="y")
exogs_future.head()
# Out:
#                    ds  temp   hum  presion  vel  nub
# 0 2019-08-01 00:00:00  10.6  77.0   1008.8  9.3  8.0
# 1 2019-08-01 01:00:00   8.5  83.0   1008.5  7.4  8.0
# 2 2019-08-01 02:00:00   7.0  95.0   1009.1  3.6  8.0
# 3 2019-08-01 03:00:00   5.8  96.0   1009.1  5.4  8.0
# 4 2019-08-01 04:00:00   6.2  97.0   1009.4  7.6  8.0

# %%
future = pd.merge(future_12h, exogs_future, on="ds")
future
# Out:
#                     ds  temp   hum  presion   vel  nub
# 0  2019-08-01 00:00:00  10.6  77.0   1008.8   9.3  8.0
# 1  2019-08-01 01:00:00   8.5  83.0   1008.5   7.4  8.0
# 2  2019-08-01 02:00:00   7.0  95.0   1009.1   3.6  8.0
# 3  2019-08-01 03:00:00   5.8  96.0   1009.1   5.4  8.0
# 4  2019-08-01 04:00:00   6.2  97.0   1009.4   7.6  8.0
# 5  2019-08-01 05:00:00   8.2  65.0   1009.1   5.4  8.0
# 6  2019-08-01 06:00:00   6.9  68.0   1008.9   7.4  8.0
# 7  2019-08-01 07:00:00   7.1  66.0   1008.3   3.6  7.0
# 8  2019-08-01 08:00:00   8.9  50.0   1008.0  14.8  7.0
# 9  2019-08-01 09:00:00   8.3  50.0   1008.2  11.2  7.0
# 10 2019-08-01 10:00:00   6.7  59.0   1008.8  13.0  7.0
# 11 2019-08-01 11:00:00   5.3  61.0   1009.5  13.0  6.0

# %%
forecast_12h = model_prophet.predict(future_12h)

# %%
forecast = pd.DataFrame()

# %%
pd.concat([forecast, forecast_12h])
# Out:
#                     ds       trend  yhat_lower  yhat_upper  trend_lower  \
# 0  2019-08-01 00:00:00  118.892376 -242.136815  116.404857   118.892376
# 1  2019-08-01 01:00:00  118.747641 -249.584632  118.719563   118.747641
# 2  2019-08-01 02:00:00  118.602906 -224.622778  122.598277   118.602906
# 3  2019-08-01 03:00:00  118.458171 -220.912698  138.914391   118.458171
# 4  2019-08-01 04:00:00  118.313436 -219.715461  134.144579   118.313436
# 5  2019-08-01 05:00:00  118.168701 -239.542157  115.517573   118.168701
# 6  2019-08-01 06:00:00  118.023966 -244.557946   91.187402   118.023954
# 7  2019-08-01 07:00:00  117.879231 -220.689140  134.232921   117.878038
# 8  2019-08-01 08:00:00  117.734496 -126.508132  218.753521   117.731713
# 9  2019-08-01 09:00:00  117.589761   38.991062  380.737017   117.585032
# 10 2019-08-01 10:00:00  117.445026  217.457448  587.217205   117.438194
# 11 2019-08-01 11:00:00  117.300292  382.047968  743.616732   117.290738
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    118.892376     -175.634030           -175.634030           -175.634030
# 1    118.747641     -177.825432           -177.825432           -177.825432
# 2    118.602906     -167.244241           -167.244241           -167.244241
# 3    118.458171     -155.340500           -155.340500           -155.340500
# 4    118.313436     -157.380143           -157.380143           -157.380143
# 5    118.168701     -175.728590           -175.728590           -175.728590
# 6    118.024729     -190.240409           -190.240409           -190.240409
# 7    117.881366     -165.612605           -165.612605           -165.612605
# 8    117.737788      -73.185825            -73.185825            -73.185825
# 9    117.595245       86.868194             86.868194             86.868194
# 10   117.452934      278.526578            278.526578            278.526578
# 11   117.311412      443.707945            443.707945            443.707945
#
#          daily  daily_lower  daily_upper  multiplicative_terms  \
# 0  -175.634030  -175.634030  -175.634030                   0.0
# 1  -177.825432  -177.825432  -177.825432                   0.0
# 2  -167.244241  -167.244241  -167.244241                   0.0
# 3  -155.340500  -155.340500  -155.340500                   0.0
# 4  -157.380143  -157.380143  -157.380143                   0.0
# 5  -175.728590  -175.728590  -175.728590                   0.0
# 6  -190.240409  -190.240409  -190.240409                   0.0
# 7  -165.612605  -165.612605  -165.612605                   0.0
# 8   -73.185825   -73.185825   -73.185825                   0.0
# 9    86.868194    86.868194    86.868194                   0.0
# 10  278.526578   278.526578   278.526578                   0.0
# 11  443.707945   443.707945   443.707945                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                          0.0                         0.0  -56.741654
# 1                          0.0                         0.0  -59.077791
# 2                          0.0                         0.0  -48.641334
# 3                          0.0                         0.0  -36.882328
# 4                          0.0                         0.0  -39.066707
# 5                          0.0                         0.0  -57.559889
# 6                          0.0                         0.0  -72.216442
# 7                          0.0                         0.0  -47.733374
# 8                          0.0                         0.0   44.548672
# 9                          0.0                         0.0  204.457956
# 10                         0.0                         0.0  395.971604
# 11                         0.0                         0.0  561.008237

# %%
forecasts = []
data = train_data.copy()
future_data = test_data.copy()
exogs_future = test_data.drop(columns="y")
for k in range(1, 24*5):
    model_prophet = Prophet(daily_seasonality=True, weekly_seasonality=False, yearly_seasonality=False)
    model_prophet.fit(data)
    future_12h = model_prophet.make_future_dataframe(1, freq="H", include_history=False)
    future_12h = pd.merge(future_12h, exogs_future, on="ds")
    forecast_12h = model_prophet.predict(future_12h)
    forecasts.append(forecast_12h)
    data = pd.concat([data, future_data.iloc[1*(k-1):1*k]])

# %%
all_forecasts = pd.concat(forecasts)

# %%
yhat = all_forecasts[["ds", "yhat"]]

# %%
yhat = yhat.set_index("ds")

# %%
ax = train.plot()
ax = test.plot(ax=ax)
yhat.plot(ax=ax)
