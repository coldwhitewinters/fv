# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.tsa.api as tsa
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pmd
from scipy.signal import medfilt
from scipy.ndimage import median_filter
# Cuidado al usar Prophet. De-registra los convertores de pandas para matplotlib, ocasionando bugs.
from fbprophet import Prophet

# %%
pd.plotting.register_matplotlib_converters() # Volvemos a registrar los convertores.
plt.rcParams['figure.figsize'] = [16, 4]

# %%
def median_filter(ds, window=5, th=5):
    rolling_median = ds.rolling(window, center=True).median()
    difference = ds - rolling_median
    outliers = difference.abs() > th*difference.std()
    return outliers

# %%
orig_weather = pd.read_csv("../data/pronóstico_horario_abril_sept.csv", parse_dates=["fecha"], index_col="fecha")

# %%
weather = orig_weather.copy()

# %%
weather.temp.diff().dropna().plot()

# %%
#weather = weather.dropna(how="any")

# %%
weather.loc[:, "hora"] = weather.index.hour
weather.loc[:, "dia"] = weather.index.day
weather.loc[:, "mes"] = weather.index.month

# %%
# weather.loc[:, "hora"] = weather.fecha.dt.hour
# weather.loc[:, "dia"] = weather.fecha.dt.day
# weather.loc[:, "mes"] = weather.fecha.dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-a2dd3ec598c5> in <module>
# ----> 1 weather.loc[:, "hora"] = weather.index.dt.hour
#       2 weather.loc[:, "dia"] = weather.index.dt.day
#       3 weather.loc[:, "mes"] = weather.index.dt.month
#
# AttributeError: 'DatetimeIndex' object has no attribute 'dt'

# %%
weather = weather.asfreq("H")

# %%
weather.

# %%
filtered = median_filter(weather.temp.to_numpy(), size=10)
filtered = pd.Series(filtered)

# %%
weather.head()
# Out:
#                      temp   hum  presion dir   vel  nub  prec  t_max  t_min  \
# fecha
# 2019-04-01 00:00:00  20.1  85.0   1016.3   E  14.8  6.0   0.0   28.9   18.7
# 2019-04-01 01:00:00  19.2  93.0   1016.7   E   9.4  4.0   0.0   20.1   12.5
# 2019-04-01 02:00:00  18.5  95.0   1016.7   E   3.6  0.0   0.0   20.1   12.5
# 2019-04-01 03:00:00  15.2  96.0   1016.7   S   5.4  0.0   0.0   20.1   12.5
# 2019-04-01 04:00:00  16.2  95.0   1016.3   E   7.6  4.0   0.0   20.1   12.5
#
#                                     situacion  faltante  hora  dia  mes
# fecha
# 2019-04-01 00:00:00                    Nuboso     False     0    1    4
# 2019-04-01 01:00:00           Nubes dispersas     False     1    1    4
# 2019-04-01 02:00:00                 Despejado     False     2    1    4
# 2019-04-01 03:00:00        Despejado, neblina     False     3    1    4
# 2019-04-01 04:00:00  Nubes dispersas, neblina     False     4    1    4

# %%
weather.isna().sum()
# Out:
# temp         77
# hum          83
# presion      77
# dir          73
# vel          73
# nub          73
# prec         73
# t_max        73
# t_min        73
# situacion    73
# faltante      0
# hora          0
# dia           0
# mes           0
# dtype: int64

# %%
weather = weather.loc[weather.mes != 9, :]

# %%
weather.temp.plot()

# %%
filtered.plot(ylim=(-22, 32))

# %%
weather.reset_index().temp.plot(xlim=(1500,2000), ylim=(0,20))

# %%
filtered.plot(xlim = (1500, 2000), ylim=(0,20))

# %%
filtered = medfilt(weather.temp.to_numpy(), kernel_size=5)
filtered = pd.Series(filtered)

# %%
filtered.isna().sum()
# Out:
# 73

# %%
weather.temp
# Out:
# fecha
# 2019-04-01 00:00:00    20.1
# 2019-04-01 01:00:00    19.2
# 2019-04-01 02:00:00    18.5
# 2019-04-01 03:00:00    15.2
# 2019-04-01 04:00:00    16.2
#                        ...
# 2019-08-31 19:00:00    15.6
# 2019-08-31 20:00:00    14.8
# 2019-08-31 21:00:00    13.2
# 2019-08-31 22:00:00    11.1
# 2019-08-31 23:00:00     8.9
# Freq: H, Name: temp, Length: 3672, dtype: float64

# %%
filtered
# Out:
# 0       18.5
# 1       18.5
# 2       18.5
# 3       18.5
# 4       16.2
#         ...
# 3667    13.8
# 3668    13.8
# 3669    13.6
# 3670    13.2
# 3671    13.2
# Length: 3672, dtype: float64

# %%
(filtered - weather.reset_index().temp).std()
# Out:
# 1.549464286301269

# %%
weather.temp.head()
# Out:
# fecha
# 2019-04-01 00:00:00    20.1
# 2019-04-01 01:00:00    19.2
# 2019-04-01 02:00:00    18.5
# 2019-04-01 03:00:00    15.2
# 2019-04-01 04:00:00    16.2
# Freq: H, Name: temp, dtype: float64

# %%
junio = weather.loc[weather.mes == 7, :]

# %%
junio_temp_rolling = junio.temp.rolling(5, center=True).median()

# %%
junio_temp_rolling.tail()
# Out:
# 2923    14.2
# 2924    13.4
# 2925    12.4
# 2926     NaN
# 2927     NaN
# Name: temp, dtype: float64

# %%
weather.isna().sum()
# Out:
# temp         87
# hum          87
# presion      87
# dir          87
# vel          87
# nub          87
# prec         87
# t_max        87
# t_min        87
# situacion    87
# faltante     87
# hora         87
# dia          87
# mes          87
# dtype: int64

# %%
outliers = median_filter(weather.temp.fillna(method="ffill"), 5, 5)

# %%
weather.loc[outliers, "temp"]
# Out:
# fecha
# 2019-06-10 00:00:00     5.2
# 2019-07-08 12:00:00    -1.8
# 2019-07-16 07:00:00    23.2
# 2019-07-24 10:00:00   -20.2
# 2019-07-24 11:00:00     NaN
# Name: temp, dtype: float64

# %%
weather.loc[:, "temp"].plot()
weather.loc[outliers, "temp"].plot(kind="line", xlim=("2019-04-19", "2019-04-20"))

# %%
junio.loc[outliers, "temp"] = np.nan
# Out:
# C:\Users\ariel\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
orig_weather.loc["2019-07-01":"2019-07-31", "temp"].plot()

# %%
junio.temp.plot()
junio_temp_rolling.plot()

# %%
differences = (junio.temp - junio_temp_rolling)
differences.plot()

# %%
differences[differences.abs() > 3*differences.std()]
# Out:
# 2551    23.65
# 2746   -18.85
# Name: temp, dtype: float64

# %%
temps = weather.set_index("fecha").asfreq("H").temp

# %%
temps.plot()

# %%
temps_rolling_median = temps.rolling(6, min_periods=1, center=True).median()

# %%
temps_rolling_median.isna().sum()
# Out:
# 18

# %%
temps.plot()
temps_rolling_median.plot()

# %%
adifferences = temps - temps_rolling_median

# %%
differences.plot()

# %%
differences[differences.abs() > 5*differences.std()]
# Out:
# fecha
# 2019-07-16 07:00:00    23.65
# 2019-07-24 10:00:00   -18.70
# Name: temp, dtype: float64

# %%
temps.loc["2019-07-08":"2019-07-09"].plot()

# %%
temps.loc["2019-04":"2019-04-30"].plot()

# %%
temps.loc["2019-05-01":"2019-05-31"].plot()

# %%
temps.loc["2019-06-01":"2019-06-30"].plot()

# %%
temps.loc["2019-07-01":"2019-07-31"].plot()

# %%
temps.loc["2019-08":"2019-08-31"].plot()

# %%
temps_rolling_median.loc["2019-07-08":"2019-07-09"].plot()

# %%
temps.loc["2019-06-09":"2019-06-11"].plot()

# %%
temps.iloc[1670:1690].plot()
temps_rolling_median.iloc[1670:1690].plot()

# %%
sns.relplot(y="temp", x="hora", hue="mes", data=weather, 
            height=4, aspect=3, kind="line", 
            ci=95, palette="Set1", legend="full")

# %%
sns.relplot(y="presion", x="hora", hue="mes", data=weather, 
            height=4, aspect=3, kind="line", 
            ci=95, palette="Set1", legend="full")

# %%
sns.relplot(y="hum", x="hora", hue="mes", data=weather, 
            height=4, aspect=3, kind="line", 
            ci=95, palette="Set1", legend="full")

# %%
sns.relplot(y="vel", x="hora", hue="mes", data=weather, 
            height=4, aspect=3, kind="line", 
            ci=95, palette="Set1", legend="full")

# %%
sns.relplot(y="prec", x="mes", data=weather, 
            height=4, aspect=3, kind="line", 
            ci=95, palette="Set1", legend="full")

# %%
data = pd.read_csv("./data/2019-08WeatherIBUENOSA520.csv")

# %%
data
# Out:
#      2019-08-01T03:00:38Z,2019-08-01 00:00:38,1564628438,0.0,,286,56.0,56.0,56.0,-1,"{'tempHigh': 49.1, 'tempLow': 49.1, 'tempAvg': 49.1, 'windspeedHigh': 2.0, 'windspeedLow': 2.0, 'windspeedAvg': 2.0, 'windgustHigh': 2.0, 'windgustLow': 2.0, 'windgustAvg': 2.0, 'dewptHigh': 34.1, 'dewptLow': 34.1, 'dewptAvg': 34.1, 'windchillHigh': 49.1, 'windchillLow': 49.1, 'windchillAvg': 49.1, 'heatindexHigh': 49.1, 'heatindexLow': 49.1, 'heatindexAvg': 49.1, 'pressureMax': 29.77, 'pressureMin': 29.77, 'pressureTrend': None, 'precipRate': 0.0, 'precipTotal': 0.0}"
# 0     2019-08-01T03:05:06Z,2019-08-01 00:05:06,15646...
# 1     2019-08-01T03:10:38Z,2019-08-01 00:10:38,15646...
# 2     2019-08-01T03:15:06Z,2019-08-01 00:15:06,15646...
# 3     2019-08-01T03:20:33Z,2019-08-01 00:20:33,15646...
# 4     2019-08-01T03:25:04Z,2019-08-01 00:25:04,15646...
# ...                                                 ...
# 6760  2019-08-28T23:35:15Z,2019-08-28 20:35:15,15670...
# 6761  2019-08-28T23:40:40Z,2019-08-28 20:40:40,15670...
# 6762  2019-08-28T23:45:17Z,2019-08-28 20:45:17,15670...
# 6763  2019-08-28T23:50:42Z,2019-08-28 20:50:42,15670...
# 6764  2019-08-28T23:55:14Z,2019-08-28 20:55:14,15670...
#
# [6765 rows x 1 columns]

# %%
weather.groupby("mes").size().plot(kind="bar")

# %%
sns.relplot(x="temp", y="presion", hue="mes", data=weather, 
            height=4, aspect=3)

# %%
weather.loc[:, ["fecha","temp"]].set_index("fecha").asfreq("H").plot()

# %%
weather.loc[(weather.mes == 7), ["fecha","temp"]].set_index("fecha").asfreq("H").plot()

# %%
weather.loc[(weather.mes == 7) & (weather.dia == 24) , ["fecha","temp"]].set_index("fecha").asfreq("H").plot()

# %%
sns.boxplot(x="dia", y="temp", data=weather.loc[weather.mes == 7, :])

# %%
weather.loc[(weather.mes == 7) & (weather.dia == 16), "temp"].plot()

# %%
t = weather.fecha[0]

# %%
weather.loc[:,"hora"].apply(lambda x: x < 12).head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: hora, dtype: bool

# %%
weather.loc[:, "temp"].asfreq("H").plot()

# %%
rolling_mean = weather.set_index("fecha").loc[:, ["temp", "mes", "dia", "hora"]].rolling(6).mean().reindex(temps.index)
#rolling_mean.isna().sum()
rolling_median = weather.set_index("fecha").loc[:, ["temp", "mes", "dia", "hora"]].rolling(6).median()
#weather.set_index("fecha").loc[:, "temp"].asfreq("H").plot()

# %%
temps = weather.set_index("fecha").asfreq("H").loc[:, ["temp", "mes", "dia", "hora"]].copy()

# %%
weather.set_index("fecha").loc[:, "temp"].asfreq("H").rolling(

# %%
weather.head()
# Out:
#    index               fecha  temp   hum  presion dir   vel  nub  prec  t_max  \
# 0      0 2019-04-01 00:00:00  20.1  85.0   1016.3   E  14.8  6.0   0.0   28.9
# 1      1 2019-04-01 01:00:00  19.2  93.0   1016.7   E   9.4  4.0   0.0   20.1
# 2      2 2019-04-01 02:00:00  18.5  95.0   1016.7   E   3.6  0.0   0.0   20.1
# 3      3 2019-04-01 03:00:00  15.2  96.0   1016.7   S   5.4  0.0   0.0   20.1
# 4      4 2019-04-01 04:00:00  16.2  95.0   1016.3   E   7.6  4.0   0.0   20.1
#
#    t_min                 situacion  faltante  hora  mes  dia
# 0   18.7                    Nuboso     False     0    4    1
# 1   12.5           Nubes dispersas     False     1    4    1
# 2   12.5                 Despejado     False     2    4    1
# 3   12.5        Despejado, neblina     False     3    4    1
# 4   12.5  Nubes dispersas, neblina     False     4    4    1

# %%
temps.loc[temps.mes == 7, "temp"].plot()
rolling_mean.loc[temps.mes == 7, "temp"].asfreq("H").shift(-3).interpolate(kind="linear").plot()
#rolling_median.loc[temps.mes == 6, "temp"].asfreq("H").shift(-3).interpolate().plot()

# %%
orig_weather.loc["2019-07-09":"2019-07-10", "temp"].plot()

# %%
temps.temp.rolling(6).std()
# Out:
# fecha
# 2019-04-01 00:00:00         NaN
# 2019-04-01 01:00:00         NaN
# 2019-04-01 02:00:00         NaN
# 2019-04-01 03:00:00         NaN
# 2019-04-01 04:00:00         NaN
#                          ...
# 2019-09-04 08:00:00    0.886378
# 2019-09-04 09:00:00    0.539135
# 2019-09-04 10:00:00    0.512510
# 2019-09-04 11:00:00    0.530723
# 2019-09-04 12:00:00    0.930949
# Freq: H, Name: temp, Length: 3757, dtype: float64
